# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import plotly.express as px
import plotly.graph_objects as go
import analytics_core_V04 as ac
import matplotlib.pyplot as plt
from matplotlib_venn import venn3

from typing import List, Dict, Tuple
import pandas as pd
import matplotlib.pyplot as plt
import helper_functions as cf

# %% [markdown]
# # Figure 3B

# %%
df_comp = pd.read_parquet(r'Z:\SPEC\submission\raw\figure3\report.parquet')
df_comp = df_comp[df_comp['PG.Q.Value']<0.01]
to_keep = ['C1', 'C2', 'C3', 'C4', 'A1', 'A2', 'A3', 'A4', 'B1', 'B2', 'B3', 'B4']
df_comp['reduced_id'] = df_comp['Run'].apply(lambda x: x.split('_')[-1])
df_comp = df_comp[df_comp['Run'].apply(lambda x: x.split('_')[-1]).isin(to_keep)]
to_keep1 = [['B1', 'B2', 'B3', 'B4'], ['C1', 'C2', 'C3', 'C4'], ['A1', 'A2', 'A3', 'A4']]
fin = []
for el in to_keep1:
    tmp = []
    for el1 in el:
        tmp_df = df_comp[df_comp['reduced_id'] == el1].drop_duplicates('Protein.Group')
        tmp.append(len(tmp_df))
    fin.append(tmp)
        
fin = [[5395, 6383, 4381, 6115], [6939, 6910, 6920, 6832], [7672, 7740, 7736, 7645]]
labels = ['Single shot InSol', 'Bulk InSol', 'SPEC']
colors = ['#bd8078', '#623a73', '#ff0000']  # Add your colors

# Calculate medians for bars
medians = [np.median(reps) for reps in fin]

# Create strip data for points
strip_data = []
for i, (label, reps) in enumerate(zip(labels, fin)):
    for rep_val in reps:
        strip_data.append({'Category': label, 'Value': rep_val})

strip_df = pd.DataFrame(strip_data)

# Create strip plot
fig = px.strip(strip_df, x='Category', y='Value', 
               category_orders={'Category': labels})

# Update strip plot traces (points)
fig.update_traces(
    jitter=0.8,  # Adjust this value (0-1)
    marker=dict(size=18, color='black', line=dict(width=0.5, color='white'))
)

# Add bars for each category
for i, (label, median, color) in enumerate(zip(labels, medians, colors)):
    fig.add_trace(go.Bar(
        x=[label],
        y=[median],
        width=0.5,
        marker=dict(color=color, line=dict(width=1, color='black')),
        name=label,
        showlegend=False
    ))

fig.update_layout(
    width=600,
    height=600,
    template='plotly_white',
    xaxis_title='',
    yaxis_title='Phosphosites Identified',
    yaxis=dict(range=[0, 9000]),
    showlegend=False
)
#fig.write_image(r'D:\Projects\SPEC\figs_raw\Figure_3b.pdf', width=600, height=600)

# %% [markdown]
# # Figure 3C

# %%
cv_list = []
for el in to_keep1:
    tmp = []
    tmp_df = df_comp[df_comp['reduced_id'].isin(el)]
    tmp_df = pd.pivot_table(tmp_df, columns = 'Run', index = 'Protein.Group', values= 'PG.MaxLFQ')
    linear_values = tmp_df.iloc[:,:4]
    n_valid = linear_values.notna().sum(axis=1)
    
    cv = linear_values.std(axis=1) / linear_values.mean(axis=1)
    cv = cv.replace(0, np.nan)

    cv[n_valid < 2] = np.nan
    
    cv_list.append(cv.values)
color_palette = ['#bd8078', '#623a73', '#ff0000']
fig = go.Figure()
for i, el in enumerate(cv_list):
    fig.add_trace(go.Box(y = el, marker_color = color_palette[i]))
fig.update_layout(width = 600, height = 600, showlegend = False, template = 'plotly_white')
fig.add_hline(y = np.nanmedian(cv_list[0]), line = {'dash':'dash', 'width': 2, 'color':'#bd8078'})
fig.add_hline(y = np.nanmedian(cv_list[1]), line = {'dash':'dash', 'width': 2, 'color':'#623a73'})
fig.add_hline(y = np.nanmedian(cv_list[2]), line = {'dash':'dash', 'width': 2, 'color':'#ff0000'})
#fig.write_image(r'D:\Projects\SPEC\figs_raw\Figure_3c.pdf', width=600, height=600)

# %% [markdown]
# # Figure 3D

# %%
bulk_pivot = pd.pivot_table(df_comp[df_comp['reduced_id'].isin(to_keep1[1])], columns = 'Run', index = 'Protein.Group', values= 'PG.MaxLFQ')
spec_pivot = pd.pivot_table(df_comp[df_comp['reduced_id'].isin(to_keep1[2])], columns = 'Run', index = 'Protein.Group', values= 'PG.MaxLFQ')
bulk_pivot['mean'] = bulk_pivot.apply(np.mean, axis = 1)
spec_pivot['mean'] = spec_pivot.apply(np.mean, axis = 1)
merged = pd.merge(bulk_pivot[['mean']], spec_pivot[['mean']], left_index=True, right_index=True, suffixes=('_bulk', '_spec'))
from scipy.stats import gaussian_kde
from scipy.stats import gaussian_kde, pearsonr, spearmanr

# Calculate kernel density
x = np.log10(merged['mean_bulk'])
y = np.log10(merged['mean_spec'])

# Remove any NaN or inf values
mask = np.isfinite(x) & np.isfinite(y)
x_clean = x[mask]
y_clean = y[mask]

# Calculate the point density
xy = np.vstack([x_clean, y_clean])
z = gaussian_kde(xy)(xy)


pearson_r, pearson_p = pearsonr(x_clean, y_clean)
spearman_r, spearman_p = spearmanr(x_clean, y_clean)

# Create figure with density coloring
fig = go.Figure()
fig.add_trace(go.Scatter(
    x=x_clean, 
    y=y_clean, 
    mode='markers',
    marker=dict(
        size=5,
        color=z,  # Color by density
        colorscale='inferno',  # Or 'Blues', 'Reds', 'Plasma', etc.
        showscale=True,
        colorbar=dict(title="Density"),
        line=dict(width=0)
    )
))

fig.update_layout(
    width=600, 
    height=600, 
    template='simple_white',
    xaxis_title='log10(mean_bulk)',
    yaxis_title='log10(mean_spec)'
)

fig.show()
#fig.write_image(r'D:\Projects\SPEC\figs_raw\Figure_3d.pdf', width=600, height=600)

# %% [markdown]
# # Figure 3E

# %%
from scipy.stats import gaussian_kde
from scipy.stats import gaussian_kde, pearsonr, spearmanr

# Calculate kernel density
x = np.log10(spec_pivot.iloc[:,0])
y = np.log10(spec_pivot.iloc[:,1])

# Remove any NaN or inf values
mask = np.isfinite(x) & np.isfinite(y)
x_clean = x[mask]
y_clean = y[mask]

# Calculate the point density
xy = np.vstack([x_clean, y_clean])
z = gaussian_kde(xy)(xy)

# Create figure with density coloring
fig = go.Figure()
fig.add_trace(go.Scatter(
    x=x_clean, 
    y=y_clean, 
    mode='markers',
    marker=dict(
        size=5,
        color=z,  # Color by density
        colorscale='inferno',  # Or 'Blues', 'Reds', 'Plasma', etc.
        showscale=True,
        colorbar=dict(title="Density"),
        line=dict(width=0)
    )
))

fig.update_layout(
    width=600, 
    height=600, 
    template='simple_white',
    xaxis_title='log10(mean_bulk)',
    yaxis_title='log10(mean_spec)'
)

fig.show()
#fig.write_image(r'D:\Projects\SPEC\figs_raw\Figure_3e.pdf', width=600, height=600)

# %% [markdown]
# # Figure 3F

# %%
df = pd.read_parquet(r'Z:\SPEC\submission\raw\figure3\H032_E170.parquet')
df = df[df['PG.Q.Value']<0.01]
labels = [['E9', 'E10', 'E11', 'E12'], ['E1', 'E2', 'E3', 'E4'], ['A9', 'A10', 'A11', 'A12'], ['A1', 'A2', 'A3', 'A4'],
          ['B9', 'B10', 'B11', 'B12'], ['B2', 'B3', 'B4'],['D9', 'D10', 'D11', 'D12'], ['D1', 'D2', 'D3', 'D4'],
          ['C9', 'C10', 'C11', 'C12'], ['C1', '20250520122254', 'C3', 'C4'],['F9', 'F10', 'F11', 'F12'], ['F1', 'F2', 'F3', 'F4']]
labels_flattened = [item for sublist in labels for item in sublist]
df['reduced_id'] = df['Run'].apply(lambda x: x.split('_')[-1])
df = df[df['reduced_id'].isin(labels_flattened)]
fin = []
for el in labels:
    tmp = []
    for el1 in el:
        tmp_df = df[df['reduced_id'] == el1].drop_duplicates('Protein.Group')
        tmp.append(len(tmp_df))
    fin.append(tmp)
color_palette = ['#623a73', '#ff0000']
fig = go.Figure()
for i, el in enumerate(fin):
    fig.add_trace(go.Box(y = el, boxpoints='all', pointpos=0, marker_color = color_palette[i%2], marker=dict(size=12, line = dict(width = 0.5))))
fig.update_layout(width = 1000, height = 600, template = 'none', showlegend = False)
fig.update_yaxes(range = [0,10100])
#fig.write_image(r'D:\Projects\SPEC\figs_raw\Figure_3f.pdf', width=1000, height=600)

# %% [markdown]
# # Figure 3G

# %%
df = pd.read_parquet(r'Z:\SPEC\submission\raw\figure3\H032_E177.parquet')
df = df[df['PG.Q.Value']<0.01]
to_keep = ['A1', 'A2', 'A3', 'A4', 'B1', 'B2', 'B3', 'B4']
df['reduced_id'] = df['Run'].apply(lambda x: x.split('_')[-1])
df = df[df['reduced_id'].isin(to_keep)] 
to_keep1 = [['A1', 'A2', 'A3', 'A4'], ['B1', 'B2', 'B3', 'B4']]
fin = []
for el in to_keep1:
    tmp = []
    for el1 in el:
        tmp_df = df[df['reduced_id'] == el1].drop_duplicates('Protein.Group')
        tmp.append(len(tmp_df))
    fin.append(tmp)
color_palette = ['#09316c','#1faa76']
fig = go.Figure()
for i, el in enumerate(fin):
    fig.add_trace(go.Box(y = el, boxpoints='all', pointpos=0, marker_color = color_palette[i], marker=dict(size=12, line = dict(width = 0.5))))
fig.update_layout(width = 400, height = 600, template = 'none', showlegend = False)
fig.update_yaxes(range = [0,7100])
#fig.write_image(r'D:\Projects\SPEC\figs_raw\Figure_3h.pdf', width=400, height=600)

# %% [markdown]
# # Figure 3H

# %%
df_pivot =np.log2(pd.pivot_table(df, columns = 'reduced_id', index = 'Genes', values= 'PG.MaxLFQ')).T.replace([np.inf, -np.inf], np.nan)
df_pivot['group'] = ['Soleus', 'Soleus', 'Soleus', 'Soleus', 'EDL', 'EDL', 'EDL', 'EDL']
df_pivot['sample'] = ['Soleus_1', 'Soleus_2', 'Soleus_3', 'Soleus_4', 'EDL_1', 'EDL_2', 'EDL_3', 'EDL_4']
df_pivot['subject'] = ['Soleus_1', 'Soleus_2', 'Soleus_3', 'Soleus_4', 'EDL_1', 'EDL_2', 'EDL_3', 'EDL_4']
df_pivot_filt = df_pivot.loc[:, (1 - (df_pivot.isna().sum() / len(df_pivot))) >=0.7]
df_pivot_imp = ac.imputation_mixed_norm_KNN(df_pivot_filt).reset_index()
ttest = ac.run_ttest(df_pivot_imp, 'Soleus', 'EDL')
tmp = []
for index, row in ttest.iterrows():
    if (row['log2FC'] >= 0.585) & (row['padj'] < 0.05):
        tmp.append('upreg')
    
    elif ((row['log2FC'] <= 0.585) & (row['log2FC'] >= 0)) & (row['padj'] < 0.05):
        tmp.append('almost_upreg')
    
    elif (row['log2FC'] <= -0.585) & (row['padj'] < 0.05):
        tmp.append('downreg')

    elif ((row['log2FC'] >= -0.585) & (row['log2FC'] <= 0)) & (row['padj'] < 0.05):
        tmp.append('almost_downreg')
    
    else: 
        tmp.append('noreg')

ttest['ID'] = tmp
soleus_extended = ['Myh7', 'Myh7b', 'Atp2a2', 'Tnni1', 'Tnnt1', 'Tnnc1', 'Mb', 'Ppargc1a']

edl_extended = ['Myh4', 'Atp2a1', 'Tnni2', 'Tnnt3', 'Pvalb']

genes = soleus_extended + edl_extended

fig = px.scatter(ttest, x='log2FC', y=-np.log10(ttest['padj']), color='ID', 
                 color_discrete_sequence=['#BDBDBD','#0B6299', '#77CDE6','#F7D291','#EE4811'], hover_name = 'identifier')

fig.update_traces(marker=dict(
    size=10, 
    line=dict(width=0.5, color='black')
))


fig.add_vline(x=-0.585, line_dash='dash', line_color='black')
fig.add_vline(x=0.585, line_dash='dash', line_color='black')
fig.add_hline(y=1.3, line_dash='dash', line_color='black')

fig.update_xaxes(title="log2FC (Soleus vs EDL)")
fig.update_yaxes(title='-log10(p-adjusted)')
fig.update_layout(width=600, height=600, template='plotly_white', showlegend=False)
#fig.write_image(r'D:\Projects\SPEC\figs_raw\Figure_3g.pdf', width=600, height=600)
# Out:
# z:\documents\Jupyter\SPEC-figures-main\analytics_core_V04.py:781: FutureWarning:
#
# Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[18.34733772 17.94345411 17.70359612 17.77942848 17.51184845 18.57705307
#  18.51509666 22.12437057]' has dtype incompatible with float32, please explicitly cast to a compatible dtype first.
#
# z:\documents\Jupyter\SPEC-figures-main\analytics_core_V04.py:781: FutureWarning:
#
# Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[15.65094852 15.51852989 15.65656694 15.8002224  15.97371006 15.87049389
#  15.70161438         nan]' has dtype incompatible with float32, please explicitly cast to a compatible dtype first.
#
# z:\documents\Jupyter\SPEC-figures-main\analytics_core_V04.py:781: FutureWarning:
#
# Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[17.1404686  16.92343521 17.07761701 17.16894722 19.1899395  19.07349777
#  19.81788445 19.2896347 ]' has dtype incompatible with float32, please explicitly cast to a compatible dtype first.
#
# z:\documents\Jupyter\SPEC-figures-main\analytics_core_V04.py:781: FutureWarning:
#
# Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[12.00830841 11.0358696  11.59210237 11.7321291  12.11525345 11.92542458
#  11.37571812 13.56522751]' has dtype incompatible with float32, please explicitly cast to a compatible dtype first.
#
# z:\documents\Jupyter\SPEC-figures-main\analytics_core_V04.py:781: FutureWarning:
#
# Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[19.8396136  20.22668266 20.03546143 19.2566967  19.51705551 19.03202438
#  19.71272087         nan]' has dtype incompatible with float32, please explicitly cast to a compatible dtype first.
#
# z:\documents\Jupyter\SPEC-figures-main\analytics_core_V04.py:781: FutureWarning:
#
# Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[18.86365318 18.86986542 18.82705816 18.74765587 18.41467094 18.51138878
#  19.80597115 18.14665985]' has dtype incompatible with float32, please explicitly cast to a compatible dtype first.
#
# z:\documents\Jupyter\SPEC-figures-main\analytics_core_V04.py:781: FutureWarning:
#
# Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[12.68583012 12.21157742 12.51911894 12.6599493  12.49316692 12.37652111
#  12.48510361         nan]' has dtype incompatible with float32, please explicitly cast to a compatible dtype first.
#
# z:\documents\Jupyter\SPEC-figures-main\analytics_core_V04.py:781: FutureWarning:
#
# Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[12.21351051 12.59804058 12.19629733 11.77734089 13.11824512 12.72076225
#  12.52090168         nan]' has dtype incompatible with float32, please explicitly cast to a compatible dtype first.
#
# z:\documents\Jupyter\SPEC-figures-main\analytics_core_V04.py:781: FutureWarning:
#
# Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[13.86311436 13.81011105 13.95194149 13.87505563 13.65698433 13.40915585
#  14.04200649 14.80036449]' has dtype incompatible with float32, please explicitly cast to a compatible dtype first.
#
# z:\documents\Jupyter\SPEC-figures-main\analytics_core_V04.py:781: FutureWarning:
#
# Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[12.77845001 13.30986214 13.18168068 13.08999761         nan 13.29913521
#  13.06414509 13.38742542]' has dtype incompatible with float32, please explicitly cast to a compatible dtype first.
#
# z:\documents\Jupyter\SPEC-figures-main\analytics_core_V04.py:781: FutureWarning:
#
# Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[13.50890255 13.53811646 13.61512152 13.79834557 13.54442501 13.34602261
#  14.01246166         nan]' has dtype incompatible with float32, please explicitly cast to a compatible dtype first.
#
# z:\documents\Jupyter\SPEC-figures-main\analytics_core_V04.py:781: FutureWarning:
#
# Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[16.82330894 16.72036934 16.8371404  16.96774292 16.20431519         nan
#  16.44674683 18.61353683]' has dtype incompatible with float32, please explicitly cast to a compatible dtype first.
#
# z:\documents\Jupyter\SPEC-figures-main\analytics_core_V04.py:781: FutureWarning:
#
# Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[13.73720741 14.02351284 13.77588209 13.566926   13.57723999 13.56266117
#  13.97655487 14.76228046]' has dtype incompatible with float32, please explicitly cast to a compatible dtype first.
#
# z:\documents\Jupyter\SPEC-figures-main\analytics_core_V04.py:781: FutureWarning:
#
# Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[20.14924113 20.3382206  20.45186043 19.65764236         nan 20.27807045
#  19.98244476 21.69433594]' has dtype incompatible with float32, please explicitly cast to a compatible dtype first.
#
# z:\documents\Jupyter\SPEC-figures-main\analytics_core_V04.py:781: FutureWarning:
#
# Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[15.11054325 14.50785255 14.85292753 14.94038677 15.14762306 15.06151962
#  15.31262112 18.07558632]' has dtype incompatible with float32, please explicitly cast to a compatible dtype first.
#
# z:\documents\Jupyter\SPEC-figures-main\analytics_core_V04.py:781: FutureWarning:
#
# Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[15.32470512 15.42893124 15.35660044 15.31616497 14.75520706 15.60044193
#          nan 15.4304018 ]' has dtype incompatible with float32, please explicitly cast to a compatible dtype first.
#
# z:\documents\Jupyter\SPEC-figures-main\analytics_core_V04.py:781: FutureWarning:
#
# Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[15.94909477 15.93680954 16.04468664 16.24815559 15.4887619  15.97259903
#          nan 15.34296417]' has dtype incompatible with float32, please explicitly cast to a compatible dtype first.
#
# z:\documents\Jupyter\SPEC-figures-main\analytics_core_V04.py:781: FutureWarning:
#
# Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[16.21898842 16.11840884 16.17626762 15.95997047 16.74138641 16.58072662
#  16.34461975 15.86718273]' has dtype incompatible with float32, please explicitly cast to a compatible dtype first.
#
# z:\documents\Jupyter\SPEC-figures-main\analytics_core_V04.py:781: FutureWarning:
#
# Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[18.54213524 17.82629967 18.13949903 18.05006218 18.63080978 18.32045746
#  18.59818268 20.35197449]' has dtype incompatible with float32, please explicitly cast to a compatible dtype first.
#
# z:\documents\Jupyter\SPEC-figures-main\analytics_core_V04.py:781: FutureWarning:
#
# Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[20.56243515 20.64128049 20.61960602 20.74180031 19.79200745 20.54554558
#  20.54478455         nan]' has dtype incompatible with float32, please explicitly cast to a compatible dtype first.
#
# z:\documents\Jupyter\SPEC-figures-main\analytics_core_V04.py:781: FutureWarning:
#
# Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[13.95329189 12.53022671 13.54845587 14.16184902 13.7687645  13.82857227
#  13.867136   14.02939606]' has dtype incompatible with float32, please explicitly cast to a compatible dtype first.
#
# z:\documents\Jupyter\SPEC-figures-main\analytics_core_V04.py:781: FutureWarning:
#
# Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[14.22801781 14.71353436 14.51363405 14.59934998 14.05380344 14.14683056
#          nan 15.8114233 ]' has dtype incompatible with float32, please explicitly cast to a compatible dtype first.
#
# z:\documents\Jupyter\SPEC-figures-main\analytics_core_V04.py:781: FutureWarning:
#
# Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[14.84971142 15.027215   15.13252672 15.52065372 15.38867855 15.4524765
#          nan 17.15849495]' has dtype incompatible with float32, please explicitly cast to a compatible dtype first.
#
# z:\documents\Jupyter\SPEC-figures-main\analytics_core_V04.py:781: FutureWarning:
#
# Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[14.29038334 14.08562469 14.27126439 14.43778515 15.05084038 15.03178978
#  15.27334881 14.35358715]' has dtype incompatible with float32, please explicitly cast to a compatible dtype first.
#
# z:\documents\Jupyter\SPEC-figures-main\analytics_core_V04.py:781: FutureWarning:
#
# Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[11.11754799 11.12464714 11.12464905 11.12228139 11.17972469         nan
#  11.66852856 12.88220024]' has dtype incompatible with float32, please explicitly cast to a compatible dtype first.
#
# z:\documents\Jupyter\SPEC-figures-main\analytics_core_V04.py:781: FutureWarning:
#
# Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[11.60246913 11.62892342 11.34834766 11.8301363  11.19049358 10.93290138
#          nan 10.459342  ]' has dtype incompatible with float32, please explicitly cast to a compatible dtype first.
#
# z:\documents\Jupyter\SPEC-figures-main\analytics_core_V04.py:781: FutureWarning:
#
# Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[16.78041649 15.98357042 16.07266617 15.09762859 17.14240456 17.40693283
#  16.34296036 20.27480316]' has dtype incompatible with float32, please explicitly cast to a compatible dtype first.
#
# z:\documents\Jupyter\SPEC-figures-main\analytics_core_V04.py:781: FutureWarning:
#
# Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[13.32825947 13.69616985 13.42910163 13.26287556 14.22157001 14.41218376
#  14.12607574 14.3343277 ]' has dtype incompatible with float32, please explicitly cast to a compatible dtype first.
#
# z:\documents\Jupyter\SPEC-figures-main\analytics_core_V04.py:781: FutureWarning:
#
# Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[19.87815094 19.18341064 19.56641897 19.63769531 19.44815254 21.50389671
#  19.65412331 26.04576302]' has dtype incompatible with float32, please explicitly cast to a compatible dtype first.
#
# z:\documents\Jupyter\SPEC-figures-main\analytics_core_V04.py:781: FutureWarning:
#
# Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[13.43655777 13.95105648 13.83772182 13.74177869 14.79048443 14.40820503
#  14.87073326         nan]' has dtype incompatible with float32, please explicitly cast to a compatible dtype first.
#
# z:\documents\Jupyter\SPEC-figures-main\analytics_core_V04.py:781: FutureWarning:
#
# Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[15.67999268 15.58462715 15.48929914 15.20327759 16.26186562 15.62713909
#  15.60456562         nan]' has dtype incompatible with float32, please explicitly cast to a compatible dtype first.
#
# z:\documents\Jupyter\SPEC-figures-main\analytics_core_V04.py:781: FutureWarning:
#
# Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[16.29793898 15.83112431 16.88260269 16.18008995 16.76240921 17.35169029
#  17.86860085 17.25126076]' has dtype incompatible with float32, please explicitly cast to a compatible dtype first.
#
# z:\documents\Jupyter\SPEC-figures-main\analytics_core_V04.py:781: FutureWarning:
#
# Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[18.15891584 18.04608345 17.97040558 18.46025848 18.99784851 18.72904396
#  18.70915985         nan]' has dtype incompatible with float32, please explicitly cast to a compatible dtype first.
#
# z:\documents\Jupyter\SPEC-figures-main\analytics_core_V04.py:781: FutureWarning:
#
# Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[16.12151909 15.42200947 15.50799402 14.98045349 15.42547512 15.6636343
#  16.26085281 18.01596451]' has dtype incompatible with float32, please explicitly cast to a compatible dtype first.
#
# z:\documents\Jupyter\SPEC-figures-main\analytics_core_V04.py:781: FutureWarning:
#
# Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[11.57917881 11.63081551 11.54054991 11.41165543 11.9411726  12.25971985
#  12.00677109 12.10889912]' has dtype incompatible with float32, please explicitly cast to a compatible dtype first.
#
# z:\documents\Jupyter\SPEC-figures-main\analytics_core_V04.py:781: FutureWarning:
#
# Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[12.75142892 12.85866928 12.79920769 12.5964098  13.64251423 13.4542551
#          nan 15.20002651]' has dtype incompatible with float32, please explicitly cast to a compatible dtype first.
#
# z:\documents\Jupyter\SPEC-figures-main\analytics_core_V04.py:781: FutureWarning:
#
# Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[16.28457451 15.09268379 15.83113416 16.11614418         nan 17.3217411
#  15.85801125 18.90735435]' has dtype incompatible with float32, please explicitly cast to a compatible dtype first.
#
# z:\documents\Jupyter\SPEC-figures-main\analytics_core_V04.py:781: FutureWarning:
#
# Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[14.17086983 14.38271904 13.94647121 14.16668669 14.75682545 15.09090137
#  15.13673973         nan]' has dtype incompatible with float32, please explicitly cast to a compatible dtype first.
#
# z:\documents\Jupyter\SPEC-figures-main\analytics_core_V04.py:781: FutureWarning:
#
# Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[13.93169435 13.80729866 13.96120644 14.02657795 13.93913078 14.17990112
#  14.76916981         nan]' has dtype incompatible with float32, please explicitly cast to a compatible dtype first.
#
# z:\documents\Jupyter\SPEC-figures-main\analytics_core_V04.py:781: FutureWarning:
#
# Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[13.72744846 13.84534168 13.75557105 13.693923   13.59774017 13.84056473
#  13.95012093 15.13813591]' has dtype incompatible with float32, please explicitly cast to a compatible dtype first.
#
# z:\documents\Jupyter\SPEC-figures-main\analytics_core_V04.py:781: FutureWarning:
#
# Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[12.45169544 11.36483955 11.99878661 12.17982483 11.56293869 11.49995327
#  11.23145103 14.10690212]' has dtype incompatible with float32, please explicitly cast to a compatible dtype first.
#
# z:\documents\Jupyter\SPEC-figures-main\analytics_core_V04.py:781: FutureWarning:
#
# Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[20.86152013 20.62264824 20.63172722 21.33018494         nan 22.09206772
#  20.8725605  22.93740654]' has dtype incompatible with float32, please explicitly cast to a compatible dtype first.
#
# z:\documents\Jupyter\SPEC-figures-main\analytics_core_V04.py:781: FutureWarning:
#
# Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[16.75066948 16.63386091 16.50278282 16.64813042 16.35342407 16.08220482
#  16.6515522  18.07756424]' has dtype incompatible with float32, please explicitly cast to a compatible dtype first.
#
# z:\documents\Jupyter\SPEC-figures-main\analytics_core_V04.py:781: FutureWarning:
#
# Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[15.43016624 15.35452843 15.54564253 15.85223293 15.67167091 15.20766258
#  15.37264061 19.29064178]' has dtype incompatible with float32, please explicitly cast to a compatible dtype first.
#
# z:\documents\Jupyter\SPEC-figures-main\analytics_core_V04.py:781: FutureWarning:
#
# Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[12.91769505 12.73966408 12.9392856  13.16049767         nan 13.06377983
#  13.27106571 13.68283272]' has dtype incompatible with float32, please explicitly cast to a compatible dtype first.
#
# z:\documents\Jupyter\SPEC-figures-main\analytics_core_V04.py:781: FutureWarning:
#
# Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[13.27126122 13.20562045 12.90475559 13.44084454 13.14401627         nan
#  13.39850807 15.79737854]' has dtype incompatible with float32, please explicitly cast to a compatible dtype first.
#
# z:\documents\Jupyter\SPEC-figures-main\analytics_core_V04.py:781: FutureWarning:
#
# Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[13.76010227 14.27688694 13.93182723 13.75849247 14.09467316 13.82565117
#  14.3918972  13.95775127]' has dtype incompatible with float32, please explicitly cast to a compatible dtype first.
#
# z:\documents\Jupyter\SPEC-figures-main\analytics_core_V04.py:781: FutureWarning:
#
# Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[13.66414579 13.35984421 13.84163666 13.7909565  14.41245556 14.34731293
#  13.78524017         nan]' has dtype incompatible with float32, please explicitly cast to a compatible dtype first.
#
# z:\documents\Jupyter\SPEC-figures-main\analytics_core_V04.py:781: FutureWarning:
#
# Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[13.93577194 14.37241364 14.410827   14.92429543 14.40276527 14.49582005
#          nan 14.45537663]' has dtype incompatible with float32, please explicitly cast to a compatible dtype first.
#
# z:\documents\Jupyter\SPEC-figures-main\analytics_core_V04.py:781: FutureWarning:
#
# Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[15.09356213 14.94261773 14.38123608 15.353055   14.84479332 15.29863358
#  15.6787281  16.2817955 ]' has dtype incompatible with float32, please explicitly cast to a compatible dtype first.
#
# z:\documents\Jupyter\SPEC-figures-main\analytics_core_V04.py:781: FutureWarning:
#
# Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[17.10832024 17.45866203 17.30580203 17.35042381 17.29172516 17.42754364
#  17.34217072 18.87981606]' has dtype incompatible with float32, please explicitly cast to a compatible dtype first.
#
# z:\documents\Jupyter\SPEC-figures-main\analytics_core_V04.py:781: FutureWarning:
#
# Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[16.89387894 17.35375023 17.52031898 17.25598272 17.13842773 17.10852814
#  17.54338264         nan]' has dtype incompatible with float32, please explicitly cast to a compatible dtype first.
#
# z:\documents\Jupyter\SPEC-figures-main\analytics_core_V04.py:781: FutureWarning:
#
# Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[16.30809212 15.52264595 15.82363987 15.88479265 16.75522804 16.82761002
#  16.7420063          nan]' has dtype incompatible with float32, please explicitly cast to a compatible dtype first.
#
# z:\documents\Jupyter\SPEC-figures-main\analytics_core_V04.py:781: FutureWarning:
#
# Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[18.12442398 17.79251671 17.52729607 17.81474559 17.96431541 18.29874992
#          nan 18.71862793]' has dtype incompatible with float32, please explicitly cast to a compatible dtype first.
#
# z:\documents\Jupyter\SPEC-figures-main\analytics_core_V04.py:781: FutureWarning:
#
# Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[15.8011198  16.1476326  15.80545362 15.46760845 15.11250782 15.78595638
#  15.69067478 16.75592041]' has dtype incompatible with float32, please explicitly cast to a compatible dtype first.
#
# z:\documents\Jupyter\SPEC-figures-main\analytics_core_V04.py:781: FutureWarning:
#
# Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[18.41452599 18.89559873 19.22306252 19.04920769 19.82196426 19.98032188
#  19.33915901 20.38789177]' has dtype incompatible with float32, please explicitly cast to a compatible dtype first.
#
# z:\documents\Jupyter\SPEC-figures-main\analytics_core_V04.py:781: FutureWarning:
#
# Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[15.81445726 16.04174805 15.73992729 15.66169643 15.79761314 15.64001751
#  15.73079491 16.29994011]' has dtype incompatible with float32, please explicitly cast to a compatible dtype first.
#
# z:\documents\Jupyter\SPEC-figures-main\analytics_core_V04.py:781: FutureWarning:
#
# Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[16.58852386 16.7058773  16.30953217 16.53464444 16.78278732 16.93290138
#          nan 18.01268578]' has dtype incompatible with float32, please explicitly cast to a compatible dtype first.
#
# z:\documents\Jupyter\SPEC-figures-main\analytics_core_V04.py:781: FutureWarning:
#
# Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[18.9795208  19.06653086 18.67302895 19.54704285 19.65864754 20.10027695
#          nan 23.52105713]' has dtype incompatible with float32, please explicitly cast to a compatible dtype first.
#
# z:\documents\Jupyter\SPEC-figures-main\analytics_core_V04.py:781: FutureWarning:
#
# Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[16.17326546 16.87148476 16.64311091 16.88458252 16.45981789 16.38664818
#  16.07078362 17.02852249]' has dtype incompatible with float32, please explicitly cast to a compatible dtype first.
#
# z:\documents\Jupyter\SPEC-figures-main\analytics_core_V04.py:781: FutureWarning:
#
# Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[16.74155617 15.73124123 16.33704058 16.53832436 15.45821953 17.3003521
#          nan 21.7357769 ]' has dtype incompatible with float32, please explicitly cast to a compatible dtype first.
#
# z:\documents\Jupyter\SPEC-figures-main\analytics_core_V04.py:781: FutureWarning:
#
# Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[16.4397049  16.63893509 16.74342473 17.15163422 16.22643852 16.42023277
#  16.46785736 16.83745766]' has dtype incompatible with float32, please explicitly cast to a compatible dtype first.
#
# z:\documents\Jupyter\SPEC-figures-main\analytics_core_V04.py:781: FutureWarning:
#
# Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[11.97143396 11.69110107 12.18723965 12.03596115 12.08763313 12.13027287
#  13.19783783 12.36093807]' has dtype incompatible with float32, please explicitly cast to a compatible dtype first.
#
# z:\documents\Jupyter\SPEC-figures-main\analytics_core_V04.py:781: FutureWarning:
#
# Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[17.87713242 17.23573303 17.54193624 17.51294327 17.85019493 18.57128334
#  17.63942146 21.96583176]' has dtype incompatible with float32, please explicitly cast to a compatible dtype first.
#
# z:\documents\Jupyter\SPEC-figures-main\analytics_core_V04.py:781: FutureWarning:
#
# Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[18.65499369 18.76372528 18.53214645 18.66910934         nan 18.5160923
#  19.2036438  19.8472271 ]' has dtype incompatible with float32, please explicitly cast to a compatible dtype first.
#
# z:\documents\Jupyter\SPEC-figures-main\analytics_core_V04.py:781: FutureWarning:
#
# Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[20.07026863 20.3846035  19.95498721 19.41008949 20.63095284 20.17959404
#  19.91578674         nan]' has dtype incompatible with float32, please explicitly cast to a compatible dtype first.
#
# z:\documents\Jupyter\SPEC-figures-main\analytics_core_V04.py:781: FutureWarning:
#
# Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[13.99975872 13.88067913 13.9395291  13.93814945 14.16600132 14.01185703
#  14.46072388         nan]' has dtype incompatible with float32, please explicitly cast to a compatible dtype first.
#
# z:\documents\Jupyter\SPEC-figures-main\analytics_core_V04.py:781: FutureWarning:
#
# Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[14.11120033 13.82827377 13.92550087 13.95499166         nan 14.15435028
#  13.93942833 16.16650391]' has dtype incompatible with float32, please explicitly cast to a compatible dtype first.
#
# z:\documents\Jupyter\SPEC-figures-main\analytics_core_V04.py:781: FutureWarning:
#
# Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[11.50596778 11.73316669 11.40128803 11.3834486  12.2596674  13.23762417
#  12.56611729 13.08242607]' has dtype incompatible with float32, please explicitly cast to a compatible dtype first.
#
# z:\documents\Jupyter\SPEC-figures-main\analytics_core_V04.py:781: FutureWarning:
#
# Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[13.04402924 12.70874214 13.04160754 13.37205124 12.67442894 12.72668839
#  12.97512817 13.80891609]' has dtype incompatible with float32, please explicitly cast to a compatible dtype first.
#
# z:\documents\Jupyter\SPEC-figures-main\analytics_core_V04.py:781: FutureWarning:
#
# Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[11.64240106 10.67134666 12.25117588 12.00468063 10.91224957 11.21609116
#          nan 12.72242641]' has dtype incompatible with float32, please explicitly cast to a compatible dtype first.
#
# z:\documents\Jupyter\SPEC-figures-main\analytics_core_V04.py:781: FutureWarning:
#
# Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[15.73589897 15.86050797 15.82186254 15.86918068 16.05674553 16.03918266
#  15.34613609 17.96523666]' has dtype incompatible with float32, please explicitly cast to a compatible dtype first.
#
# z:\documents\Jupyter\SPEC-figures-main\analytics_core_V04.py:781: FutureWarning:
#
# Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[18.12420845 17.74221992 17.52666219 16.7135582  17.1742115  17.45069122
#  17.31157875         nan]' has dtype incompatible with float32, please explicitly cast to a compatible dtype first.
#
# z:\documents\Jupyter\SPEC-figures-main\analytics_core_V04.py:781: FutureWarning:
#
# Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[13.45350552 13.3543005  13.48586973 13.64980316 14.18052006         nan
#  13.57975006 12.73794556]' has dtype incompatible with float32, please explicitly cast to a compatible dtype first.
#
# z:\documents\Jupyter\SPEC-figures-main\analytics_core_V04.py:781: FutureWarning:
#
# Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[13.43612194 13.0002861  13.42033005 13.28557936 13.74826622 13.9226017
#  13.75591946 14.71030426]' has dtype incompatible with float32, please explicitly cast to a compatible dtype first.
#
# z:\documents\Jupyter\SPEC-figures-main\analytics_core_V04.py:781: FutureWarning:
#
# Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[13.90381813 14.21615569 14.32255554 14.42209339 14.46062756 14.84077072
#  14.82300568 15.6935873 ]' has dtype incompatible with float32, please explicitly cast to a compatible dtype first.
#
# z:\documents\Jupyter\SPEC-figures-main\analytics_core_V04.py:781: FutureWarning:
#
# Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[15.89520931 15.71352577 16.55667305 16.05513604 16.50424194 16.58201599
#  16.82435799         nan]' has dtype incompatible with float32, please explicitly cast to a compatible dtype first.
#
# z:\documents\Jupyter\SPEC-figures-main\analytics_core_V04.py:781: FutureWarning:
#
# Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[14.99921513 15.10662842 14.89465332 15.00016562 14.05767918 13.91149902
#          nan 14.16982651]' has dtype incompatible with float32, please explicitly cast to a compatible dtype first.
#
# z:\documents\Jupyter\SPEC-figures-main\analytics_core_V04.py:781: FutureWarning:
#
# Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[16.90300179 16.45972824 16.69492849 16.72205544 16.7170887  16.63055038
#  16.05737495 18.27435875]' has dtype incompatible with float32, please explicitly cast to a compatible dtype first.
#
# z:\documents\Jupyter\SPEC-figures-main\analytics_core_V04.py:781: FutureWarning:
#
# Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[18.69062233 17.91140938 18.14485995 17.83254814 18.25323677 18.67178535
#  19.16677666 19.01087379]' has dtype incompatible with float32, please explicitly cast to a compatible dtype first.
#
# z:\documents\Jupyter\SPEC-figures-main\analytics_core_V04.py:781: FutureWarning:
#
# Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[12.80482864 12.56544685 12.82552179 13.10628986 11.59469509 12.03795719
#  13.25737286 12.47111797]' has dtype incompatible with float32, please explicitly cast to a compatible dtype first.
#
# z:\documents\Jupyter\SPEC-figures-main\analytics_core_V04.py:781: FutureWarning:
#
# Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[13.00414817 13.46484661 12.93797493 12.60962296 14.21088409 14.34877777
#  14.51333237 13.83233929]' has dtype incompatible with float32, please explicitly cast to a compatible dtype first.
#
# z:\documents\Jupyter\SPEC-figures-main\analytics_core_V04.py:781: FutureWarning:
#
# Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[12.6477766  12.54960791 12.72769547 12.27335167 12.32425308 12.46481228
#  13.17767143         nan]' has dtype incompatible with float32, please explicitly cast to a compatible dtype first.
#
# z:\documents\Jupyter\SPEC-figures-main\analytics_core_V04.py:781: FutureWarning:
#
# Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[19.90596199 20.10253716 19.99067243 19.96351814 19.38287735 19.81043434
#  20.36118317         nan]' has dtype incompatible with float32, please explicitly cast to a compatible dtype first.
#
# z:\documents\Jupyter\SPEC-figures-main\analytics_core_V04.py:781: FutureWarning:
#
# Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[12.18652153 12.10457516 12.8640337  12.38504346 12.58590508 13.26442242
#  12.57236767 14.24608898]' has dtype incompatible with float32, please explicitly cast to a compatible dtype first.
#
# z:\documents\Jupyter\SPEC-figures-main\analytics_core_V04.py:781: FutureWarning:
#
# Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[15.26078987 15.00725937 15.15423457 15.19465446 14.80827999 14.71603966
#          nan 15.38163757]' has dtype incompatible with float32, please explicitly cast to a compatible dtype first.
#
# z:\documents\Jupyter\SPEC-figures-main\analytics_core_V04.py:781: FutureWarning:
#
# Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[16.76028061 16.73261833 16.91449038 17.2505722  16.68446732 16.53283119
#  16.26651764 15.82814503]' has dtype incompatible with float32, please explicitly cast to a compatible dtype first.
#
# z:\documents\Jupyter\SPEC-figures-main\analytics_core_V04.py:781: FutureWarning:
#
# Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[14.46763484 14.62642384 14.15996838 14.6165123  14.49698353         nan
#  14.88286495 15.32204819]' has dtype incompatible with float32, please explicitly cast to a compatible dtype first.
#
# z:\documents\Jupyter\SPEC-figures-main\analytics_core_V04.py:781: FutureWarning:
#
# Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[22.43786049 22.37207413 22.30216599 22.45417023 21.91622798 20.33716393
#  21.21702766 24.19449234]' has dtype incompatible with float32, please explicitly cast to a compatible dtype first.
#
# z:\documents\Jupyter\SPEC-figures-main\analytics_core_V04.py:781: FutureWarning:
#
# Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[15.60253429 15.52470303 15.39361858 15.39122677 15.2375536  15.6462841
#  15.41526604 15.43303458]' has dtype incompatible with float32, please explicitly cast to a compatible dtype first.
#
# z:\documents\Jupyter\SPEC-figures-main\analytics_core_V04.py:781: FutureWarning:
#
# Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[12.99317932 13.28298092 13.2787466  13.28501987 12.82200813 12.11858463
#  12.78387928 12.57482402]' has dtype incompatible with float32, please explicitly cast to a compatible dtype first.
#
# z:\documents\Jupyter\SPEC-figures-main\analytics_core_V04.py:781: FutureWarning:
#
# Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[23.31839943 23.99749756 23.52715874 23.35106659 23.03220558 23.02153015
#  22.78637441 22.3053875 ]' has dtype incompatible with float32, please explicitly cast to a compatible dtype first.
#
# z:\documents\Jupyter\SPEC-figures-main\analytics_core_V04.py:781: FutureWarning:
#
# Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[18.0619297  17.68324089 18.06326866 18.17310524 17.90014076 17.56888008
#  18.10806656 17.85902913]' has dtype incompatible with float32, please explicitly cast to a compatible dtype first.
#
# z:\documents\Jupyter\SPEC-figures-main\analytics_core_V04.py:781: FutureWarning:
#
# Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[18.32273483 18.21015167 18.61425209 17.89470482 18.71795654 18.68072319
#  19.34853554 18.91573842]' has dtype incompatible with float32, please explicitly cast to a compatible dtype first.
#
# z:\documents\Jupyter\SPEC-figures-main\analytics_core_V04.py:781: FutureWarning:
#
# Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[18.65026855 18.03357315 18.32302475 18.28523254 18.22997284 18.36131668
#  19.06615067 18.55248006]' has dtype incompatible with float32, please explicitly cast to a compatible dtype first.
#
# z:\documents\Jupyter\SPEC-figures-main\analytics_core_V04.py:781: FutureWarning:
#
# Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[18.05312347 17.06992912 18.03844643 17.91028214 17.59344482 17.49460602
#  18.9303786  21.70308495]' has dtype incompatible with float32, please explicitly cast to a compatible dtype first.
#
# z:\documents\Jupyter\SPEC-figures-main\analytics_core_V04.py:781: FutureWarning:
#
# Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[16.99513245 17.08269882 17.17898369 16.87020683 16.82132721 17.12208939
#  17.22654724 17.05665461]' has dtype incompatible with float32, please explicitly cast to a compatible dtype first.
#
# z:\documents\Jupyter\SPEC-figures-main\analytics_core_V04.py:781: FutureWarning:
#
# Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[12.88843536 12.17968941 13.12244034 12.4029417  12.37920952 11.92181015
#  12.45051861 12.25051276]' has dtype incompatible with float32, please explicitly cast to a compatible dtype first.
#
# z:\documents\Jupyter\SPEC-figures-main\analytics_core_V04.py:781: FutureWarning:
#
# Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[15.36450768 15.27566242 15.29573917 15.24902916 15.51033719 14.81145287
#  14.97126389 16.74829483]' has dtype incompatible with float32, please explicitly cast to a compatible dtype first.
#
# z:\documents\Jupyter\SPEC-figures-main\analytics_core_V04.py:781: FutureWarning:
#
# Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[14.18093204 14.52549648 14.42223072 13.70704365 20.06288338 13.84656811
#  19.29233964 23.96756744]' has dtype incompatible with float32, please explicitly cast to a compatible dtype first.
#
# z:\documents\Jupyter\SPEC-figures-main\analytics_core_V04.py:781: FutureWarning:
#
# Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[13.97528648 13.94847679 13.98513889 13.83097458 13.79609776 13.56005573
#  14.21588135 13.85734495]' has dtype incompatible with float32, please explicitly cast to a compatible dtype first.
#
# z:\documents\Jupyter\SPEC-figures-main\analytics_core_V04.py:781: FutureWarning:
#
# Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[20.25970459 19.83668709 20.2782917  19.86639404 19.53593063 18.89870262
#  19.9717617  19.46879832]' has dtype incompatible with float32, please explicitly cast to a compatible dtype first.
#
# z:\documents\Jupyter\SPEC-figures-main\analytics_core_V04.py:781: FutureWarning:
#
# Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[13.33456802 13.53873348 13.59652901 13.15270996 12.79824352 13.62276459
#  13.46951485 13.29684099]' has dtype incompatible with float32, please explicitly cast to a compatible dtype first.
#
# z:\documents\Jupyter\SPEC-figures-main\analytics_core_V04.py:781: FutureWarning:
#
# Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[19.53670883 19.68320465 19.67814255 19.72853851 19.92559115 19.31337738
#  18.20233536 22.26106071]' has dtype incompatible with float32, please explicitly cast to a compatible dtype first.
#
# z:\documents\Jupyter\SPEC-figures-main\analytics_core_V04.py:781: FutureWarning:
#
# Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[13.51054001 13.66299152 14.02714443 14.4207592  14.52453613 14.64115047
#  14.92333603 14.69634088]' has dtype incompatible with float32, please explicitly cast to a compatible dtype first.
#
# z:\documents\Jupyter\SPEC-figures-main\analytics_core_V04.py:781: FutureWarning:
#
# Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[18.83526993 18.75842476 18.79415131 18.79235268 17.16892815 16.98819733
#  17.83701324 17.33137957]' has dtype incompatible with float32, please explicitly cast to a compatible dtype first.
#
# z:\documents\Jupyter\SPEC-figures-main\analytics_core_V04.py:781: FutureWarning:
#
# Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[14.72207451 15.21461296 15.31370163 15.52394104 15.15691376 13.60195923
#  13.68953609 14.14946969]' has dtype incompatible with float32, please explicitly cast to a compatible dtype first.
#
# z:\documents\Jupyter\SPEC-figures-main\analytics_core_V04.py:781: FutureWarning:
#
# Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[16.31880379 16.75127029 17.23755836 17.17284203 16.65363312 16.51829338
#  17.19705391 16.78966014]' has dtype incompatible with float32, please explicitly cast to a compatible dtype first.
#
# z:\documents\Jupyter\SPEC-figures-main\analytics_core_V04.py:781: FutureWarning:
#
# Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[12.71372414 13.06943035 13.52334023 13.19629097 12.45480919 13.16309738
#  13.28909492 12.9690005 ]' has dtype incompatible with float32, please explicitly cast to a compatible dtype first.
#
# z:\documents\Jupyter\SPEC-figures-main\analytics_core_V04.py:781: FutureWarning:
#
# Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[13.25739765 13.31879902 13.58284569 13.36509323 12.82681942 12.94536114
#  12.85187626 12.87468561]' has dtype incompatible with float32, please explicitly cast to a compatible dtype first.
#
# z:\documents\Jupyter\SPEC-figures-main\analytics_core_V04.py:781: FutureWarning:
#
# Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[12.81958008 12.65535736 13.20567513 12.97228718 12.65792179 12.97374153
#  13.22368717 12.9517835 ]' has dtype incompatible with float32, please explicitly cast to a compatible dtype first.
#
# z:\documents\Jupyter\SPEC-figures-main\analytics_core_V04.py:781: FutureWarning:
#
# Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[17.52251434 17.32927132 17.31752586 17.84266663 17.21492958 17.45531082
#  18.2975839  20.22251129]' has dtype incompatible with float32, please explicitly cast to a compatible dtype first.
#
# z:\documents\Jupyter\SPEC-figures-main\analytics_core_V04.py:781: FutureWarning:
#
# Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[20.49634171 20.31968689 19.90684319 20.27277756 19.14886284 18.9954567
#  19.33008766 19.15813573]' has dtype incompatible with float32, please explicitly cast to a compatible dtype first.
#
# z:\documents\Jupyter\SPEC-figures-main\analytics_core_V04.py:781: FutureWarning:
#
# Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[18.47232628 18.03362846 18.45557022 18.82037354 20.32927831 19.48461723
#  19.37462807 22.12858963]' has dtype incompatible with float32, please explicitly cast to a compatible dtype first.
#
# z:\documents\Jupyter\SPEC-figures-main\analytics_core_V04.py:781: FutureWarning:
#
# Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[22.3090744  21.12185669 22.16351509 21.98177719 22.33618355 22.53361829
#  22.08578873 23.1788826 ]' has dtype incompatible with float32, please explicitly cast to a compatible dtype first.
#
# z:\documents\Jupyter\SPEC-figures-main\analytics_core_V04.py:781: FutureWarning:
#
# Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[17.33395386 17.57147789 17.45763016 17.20565224 17.5229702  17.57623291
#  17.74183846 17.61368052]' has dtype incompatible with float32, please explicitly cast to a compatible dtype first.
#
# z:\documents\Jupyter\SPEC-figures-main\analytics_core_V04.py:781: FutureWarning:
#
# Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[13.32602978 13.32615566 13.78483009 12.7289896  13.18892956 12.71486568
#  13.84548569 13.24976031]' has dtype incompatible with float32, please explicitly cast to a compatible dtype first.
#
# z:\documents\Jupyter\SPEC-figures-main\analytics_core_V04.py:781: FutureWarning:
#
# Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[22.59719276 21.68013573 21.92275429 22.16207314 22.04766273 22.13188744
#  22.66207314 22.2805411 ]' has dtype incompatible with float32, please explicitly cast to a compatible dtype first.
#
# z:\documents\Jupyter\SPEC-figures-main\analytics_core_V04.py:781: FutureWarning:
#
# Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[18.39422989 18.2140522  19.13630676 19.0750103  18.36479759 18.5499897
#  19.05829239 18.65769323]' has dtype incompatible with float32, please explicitly cast to a compatible dtype first.
#
# z:\documents\Jupyter\SPEC-figures-main\analytics_core_V04.py:781: FutureWarning:
#
# Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[18.10025215 17.90143204 17.85267067 17.98162842 17.25804329 16.7561264
#  16.82196045 16.94537671]' has dtype incompatible with float32, please explicitly cast to a compatible dtype first.
#
# z:\documents\Jupyter\SPEC-figures-main\analytics_core_V04.py:781: FutureWarning:
#
# Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[16.46196365 16.35500145 16.07704735 16.02680969 16.65991052 16.36926651
#  15.58739376 18.02307129]' has dtype incompatible with float32, please explicitly cast to a compatible dtype first.
#
# z:\documents\Jupyter\SPEC-figures-main\analytics_core_V04.py:781: FutureWarning:
#
# Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[13.61389446 13.57405663 12.99034882 13.24311638 12.94096088 13.78899733
#  13.45865059 14.96738052]' has dtype incompatible with float32, please explicitly cast to a compatible dtype first.
#
# z:\documents\Jupyter\SPEC-figures-main\analytics_core_V04.py:781: FutureWarning:
#
# Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[19.50019836 19.01688004 19.55008125 19.20400047 18.76002693 18.75608444
#  18.80205727 18.77272288]' has dtype incompatible with float32, please explicitly cast to a compatible dtype first.
#
# z:\documents\Jupyter\SPEC-figures-main\analytics_core_V04.py:781: FutureWarning:
#
# Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[16.90988731 16.87855339 16.8125515  16.97708511 16.0416832  15.94929028
#  16.63058853 16.20718733]' has dtype incompatible with float32, please explicitly cast to a compatible dtype first.
#
# z:\documents\Jupyter\SPEC-figures-main\analytics_core_V04.py:781: FutureWarning:
#
# Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[12.2737608  12.26580429 12.35976124 12.33703613 11.66447163 11.68346119
#  12.34911537 11.89901606]' has dtype incompatible with float32, please explicitly cast to a compatible dtype first.
#
# z:\documents\Jupyter\SPEC-figures-main\analytics_core_V04.py:781: FutureWarning:
#
# Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[15.01131916 14.69959259 14.8961792  14.91119099 14.56298161 14.35967731
#  14.38339043 14.43534978]' has dtype incompatible with float32, please explicitly cast to a compatible dtype first.
#
# z:\documents\Jupyter\SPEC-figures-main\analytics_core_V04.py:781: FutureWarning:
#
# Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[21.29802704 21.08703041 21.10890198 21.19583702 19.79453468 19.4066925
#  19.68288994 19.62803904]' has dtype incompatible with float32, please explicitly cast to a compatible dtype first.
#
# z:\documents\Jupyter\SPEC-figures-main\analytics_core_V04.py:781: FutureWarning:
#
# Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[17.24558258 17.46628952 17.19692802 17.38849068 15.96082878 16.54236666
#  16.90833282 16.75793839]' has dtype incompatible with float32, please explicitly cast to a compatible dtype first.
#
# ...
#  16.48185539 16.14864985]' has dtype incompatible with float32, please explicitly cast to a compatible dtype first.
#
# z:\documents\Jupyter\SPEC-figures-main\analytics_core_V04.py:781: FutureWarning:
#
# Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[15.99465466 15.54499722 15.75731087 15.52823257 15.44454479 15.39606476
#  16.09236145 15.64432367]' has dtype incompatible with float32, please explicitly cast to a compatible dtype first.
#
# z:\documents\Jupyter\SPEC-figures-main\analytics_core_V04.py:781: FutureWarning:
#
# Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[14.57981205 14.7328558  14.55820084 14.66444969 14.13869762 14.59363079
#  14.48585065 14.72522354]' has dtype incompatible with float32, please explicitly cast to a compatible dtype first.
#
# z:\documents\Jupyter\SPEC-figures-main\analytics_core_V04.py:781: FutureWarning:
#
# Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[20.7606411  20.72564125 20.83934021 20.81791687 18.78263474 18.45594597
#  19.00219345 18.74692472]' has dtype incompatible with float32, please explicitly cast to a compatible dtype first.
#
# z:\documents\Jupyter\SPEC-figures-main\analytics_core_V04.py:781: FutureWarning:
#
# Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[19.44651604 19.4102459  19.40179634 19.38234329 17.24342346 16.84356117
#  17.43918419 17.17538961]' has dtype incompatible with float32, please explicitly cast to a compatible dtype first.
#
# z:\documents\Jupyter\SPEC-figures-main\analytics_core_V04.py:781: FutureWarning:
#
# Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[19.45709038 18.87723351 19.13929939 18.9890213  19.395298   19.32057571
#  19.81336975 19.50974782]' has dtype incompatible with float32, please explicitly cast to a compatible dtype first.
#
# z:\documents\Jupyter\SPEC-figures-main\analytics_core_V04.py:781: FutureWarning:
#
# Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[15.18387604 14.83101463 14.71824741 14.59092045 15.42652861 15.00555325
#  14.68998718 16.58404541]' has dtype incompatible with float32, please explicitly cast to a compatible dtype first.
#
# z:\documents\Jupyter\SPEC-figures-main\analytics_core_V04.py:781: FutureWarning:
#
# Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[18.31940269 18.06385231 18.54549026 18.60118675 17.84651375 17.63336754
#  17.80550575 17.76179568]' has dtype incompatible with float32, please explicitly cast to a compatible dtype first.
#
# z:\documents\Jupyter\SPEC-figures-main\analytics_core_V04.py:781: FutureWarning:
#
# Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[17.45087051 17.44810677 17.25047112 17.45349884 16.7169838  16.42734528
#  16.85518074 16.66650327]' has dtype incompatible with float32, please explicitly cast to a compatible dtype first.
#
# z:\documents\Jupyter\SPEC-figures-main\analytics_core_V04.py:781: FutureWarning:
#
# Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[19.31672668 19.42221451 19.26214027 19.36115074 18.50653458 18.50112343
#  18.45790482 18.48852094]' has dtype incompatible with float32, please explicitly cast to a compatible dtype first.
#
# z:\documents\Jupyter\SPEC-figures-main\analytics_core_V04.py:781: FutureWarning:
#
# Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[20.10019684 19.76686096 20.14279556 19.78586197 20.01323128 19.77267456
#  20.58004125 21.95421791]' has dtype incompatible with float32, please explicitly cast to a compatible dtype first.
#
# z:\documents\Jupyter\SPEC-figures-main\analytics_core_V04.py:781: FutureWarning:
#
# Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[21.49969864 21.46715164 21.53326225 21.58107376 22.87971814 22.55844307
#  21.85130692 24.22940445]' has dtype incompatible with float32, please explicitly cast to a compatible dtype first.
#
# z:\documents\Jupyter\SPEC-figures-main\analytics_core_V04.py:781: FutureWarning:
#
# Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[19.98703384 19.77453041 20.02050781 20.03539085 18.72065926 18.77858162
#  18.8874855  18.79557546]' has dtype incompatible with float32, please explicitly cast to a compatible dtype first.
#
# z:\documents\Jupyter\SPEC-figures-main\analytics_core_V04.py:781: FutureWarning:
#
# Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[18.93123436 18.637043   18.94440269 18.82359886 18.95687103 18.98403358
#  19.43837929 19.12642797]' has dtype incompatible with float32, please explicitly cast to a compatible dtype first.
#
# z:\documents\Jupyter\SPEC-figures-main\analytics_core_V04.py:781: FutureWarning:
#
# Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[17.32048607 17.96029663 17.79403496 17.46067619 17.77636147 17.52750969
#  17.82058525 17.70815214]' has dtype incompatible with float32, please explicitly cast to a compatible dtype first.
#
# z:\documents\Jupyter\SPEC-figures-main\analytics_core_V04.py:781: FutureWarning:
#
# Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[19.68708611 18.45581818 19.45391655 18.86375427 19.59914398 21.32409859
#  21.70170911 24.18188477]' has dtype incompatible with float32, please explicitly cast to a compatible dtype first.
#
# z:\documents\Jupyter\SPEC-figures-main\analytics_core_V04.py:781: FutureWarning:
#
# Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[16.67159653 16.33697319 16.29105377 16.93653679 15.4180994  15.68181801
#  16.10092767 17.2028656 ]' has dtype incompatible with float32, please explicitly cast to a compatible dtype first.
#
# z:\documents\Jupyter\SPEC-figures-main\analytics_core_V04.py:781: FutureWarning:
#
# Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[18.53856277 19.32220268 18.72538757 18.59523582 17.93690872 20.3327179
#  20.10124842 22.03411865]' has dtype incompatible with float32, please explicitly cast to a compatible dtype first.
#
# z:\documents\Jupyter\SPEC-figures-main\analytics_core_V04.py:781: FutureWarning:
#
# Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[18.02108002 18.05805206 18.03852272 17.67099571 17.42407544 17.29856873
#  17.66872597 17.30493164]' has dtype incompatible with float32, please explicitly cast to a compatible dtype first.
#
# z:\documents\Jupyter\SPEC-figures-main\analytics_core_V04.py:781: FutureWarning:
#
# Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[14.69047642 14.72145748 14.14749813 14.51981068 13.71641731 13.85383987
#  13.9904534  14.40110302]' has dtype incompatible with float32, please explicitly cast to a compatible dtype first.
#
# z:\documents\Jupyter\SPEC-figures-main\analytics_core_V04.py:781: FutureWarning:
#
# Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[14.7548542  15.26764011 14.90010262 14.89034367 14.23880005 14.63716221
#  14.81890011 14.56495412]' has dtype incompatible with float32, please explicitly cast to a compatible dtype first.
#
# z:\documents\Jupyter\SPEC-figures-main\analytics_core_V04.py:781: FutureWarning:
#
# Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[22.21418381 22.06613159 22.12943459 21.95209312 21.25186539 22.40483093
#  22.42005793 23.60347748]' has dtype incompatible with float32, please explicitly cast to a compatible dtype first.
#
# z:\documents\Jupyter\SPEC-figures-main\analytics_core_V04.py:781: FutureWarning:
#
# Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[20.23855209 20.14275742 20.12093544 20.35309982 19.370423   19.1511879
#  18.91250992 20.04757118]' has dtype incompatible with float32, please explicitly cast to a compatible dtype first.
#
# z:\documents\Jupyter\SPEC-figures-main\analytics_core_V04.py:781: FutureWarning:
#
# Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[17.77964973 17.34609795 17.41667747 17.42990494 15.94985294 16.32232634
#  16.87657738 16.14054871]' has dtype incompatible with float32, please explicitly cast to a compatible dtype first.
#
# z:\documents\Jupyter\SPEC-figures-main\analytics_core_V04.py:781: FutureWarning:
#
# Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[11.53173637 11.36112309 11.42477989 11.09618092 11.77596951 11.4539175
#  11.12474632 11.45154444]' has dtype incompatible with float32, please explicitly cast to a compatible dtype first.
#
# z:\documents\Jupyter\SPEC-figures-main\analytics_core_V04.py:781: FutureWarning:
#
# Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[25.75764084 25.6571846  25.64913177 25.63278961 23.16666412 23.99437523
#  24.14602852 23.76902262]' has dtype incompatible with float32, please explicitly cast to a compatible dtype first.
#
# z:\documents\Jupyter\SPEC-figures-main\analytics_core_V04.py:781: FutureWarning:
#
# Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[16.91572571 16.92546272 16.65835381 17.03407097 16.35777473 16.49932861
#  15.42596722 16.09435685]' has dtype incompatible with float32, please explicitly cast to a compatible dtype first.
#
# z:\documents\Jupyter\SPEC-figures-main\analytics_core_V04.py:781: FutureWarning:
#
# Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[14.37448311 14.61989784 14.4461174  14.5683918  14.67504501 14.55530643
#  14.37129593 14.53388246]' has dtype incompatible with float32, please explicitly cast to a compatible dtype first.
#
# z:\documents\Jupyter\SPEC-figures-main\analytics_core_V04.py:781: FutureWarning:
#
# Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[15.73217392 15.14150333 15.29614735 15.74834442 14.94843864 15.99673939
#  16.0610501  17.23797226]' has dtype incompatible with float32, please explicitly cast to a compatible dtype first.
#
# z:\documents\Jupyter\SPEC-figures-main\analytics_core_V04.py:781: FutureWarning:
#
# Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[15.64765263 15.74876022 16.0174427  16.08167458 15.06781769 15.09572506
#  15.99409199 15.38587825]' has dtype incompatible with float32, please explicitly cast to a compatible dtype first.
#
# z:\documents\Jupyter\SPEC-figures-main\analytics_core_V04.py:781: FutureWarning:
#
# Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[11.70153427 12.02926254 12.01817131 12.00941467 12.42681026 12.47093105
#  12.65213426 13.05866146]' has dtype incompatible with float32, please explicitly cast to a compatible dtype first.
#
# z:\documents\Jupyter\SPEC-figures-main\analytics_core_V04.py:781: FutureWarning:
#
# Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[15.35886192 15.12425137 15.07174301 15.39690208 15.26993275 15.17853451
#  15.59133593 16.32554054]' has dtype incompatible with float32, please explicitly cast to a compatible dtype first.
#
# z:\documents\Jupyter\SPEC-figures-main\analytics_core_V04.py:781: FutureWarning:
#
# Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[18.46198273 18.51219368 18.58644295 18.55954552 18.84669685 18.77179909
#  18.91311073 18.84386889]' has dtype incompatible with float32, please explicitly cast to a compatible dtype first.
#
# z:\documents\Jupyter\SPEC-figures-main\analytics_core_V04.py:781: FutureWarning:
#
# Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[12.9951086  13.20212746 12.94505692 13.25258541 11.77333832 12.5953277
#  12.79533482 13.21730995]' has dtype incompatible with float32, please explicitly cast to a compatible dtype first.
#
# z:\documents\Jupyter\SPEC-figures-main\analytics_core_V04.py:781: FutureWarning:
#
# Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[14.93418503 14.56102467 15.34671116 14.80375957 14.58863544 15.02035491
#  13.92135048 16.5510788 ]' has dtype incompatible with float32, please explicitly cast to a compatible dtype first.
#
# z:\documents\Jupyter\SPEC-figures-main\analytics_core_V04.py:781: FutureWarning:
#
# Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[21.06966209 20.93131256 21.17264175 21.13933372 21.08880997 20.95812798
#  21.48122787 21.17605527]' has dtype incompatible with float32, please explicitly cast to a compatible dtype first.
#
# z:\documents\Jupyter\SPEC-figures-main\analytics_core_V04.py:781: FutureWarning:
#
# Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[14.83199692 14.61959553 14.53740501 14.66299915 14.52620125 14.5654707
#  14.90658633 15.62808704]' has dtype incompatible with float32, please explicitly cast to a compatible dtype first.
#
# z:\documents\Jupyter\SPEC-figures-main\analytics_core_V04.py:781: FutureWarning:
#
# Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[15.37399101 15.24479485 15.4215517  14.88020325 15.17514579 14.91471386
#  15.19737911 15.41334438]' has dtype incompatible with float32, please explicitly cast to a compatible dtype first.
#
# z:\documents\Jupyter\SPEC-figures-main\analytics_core_V04.py:781: FutureWarning:
#
# Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[14.81402206 14.68765163 15.12021828 14.78207874 14.69517517 14.43527889
#  14.8045613  15.28322983]' has dtype incompatible with float32, please explicitly cast to a compatible dtype first.
#
# z:\documents\Jupyter\SPEC-figures-main\analytics_core_V04.py:781: FutureWarning:
#
# Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[13.77971363 13.67238426 14.04313564 14.19898224 13.75967407 13.91641331
#  13.95219612 13.8760945 ]' has dtype incompatible with float32, please explicitly cast to a compatible dtype first.
#
# z:\documents\Jupyter\SPEC-figures-main\analytics_core_V04.py:781: FutureWarning:
#
# Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[11.0773859  10.91722584 11.2850771  11.29039574 11.17962933 11.4788262
#  11.7524538  11.50439548]' has dtype incompatible with float32, please explicitly cast to a compatible dtype first.
#
# z:\documents\Jupyter\SPEC-figures-main\analytics_core_V04.py:781: FutureWarning:
#
# Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[14.44656277 14.73836613 14.94184971 14.79942513 14.85416317 14.28443813
#  14.80203819 14.64687983]' has dtype incompatible with float32, please explicitly cast to a compatible dtype first.
#
# z:\documents\Jupyter\SPEC-figures-main\analytics_core_V04.py:781: FutureWarning:
#
# Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[12.86002827 13.23419189 12.89906597 12.51511765 13.16743565 13.43482558
#  12.77220154 14.36483955]' has dtype incompatible with float32, please explicitly cast to a compatible dtype first.
