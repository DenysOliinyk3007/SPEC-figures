# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import plotly.express as px
import plotly.graph_objects as go
import analytics_core_V04 as ac
import matplotlib.pyplot as plt
from matplotlib_venn import venn3

from typing import List, Dict, Tuple
import pandas as pd
import matplotlib.pyplot as plt

# %%
import helper_functions as cf

# %% [markdown]
# # Supplementary Figure 1B & 1C

# %%
spec_0p25ng = pd.read_parquet(r'Z:\Tim_SPEC\K562_dilution_series_SPEC_vs_InSol\SPEC\0p25ng\report.parquet')
spec_1ng = pd.read_parquet(r'Z:\Tim_SPEC\K562_dilution_series_SPEC_vs_InSol\SPEC\1ng\report.parquet')
spec_5ng = pd.read_parquet(r'Z:\Tim_SPEC\K562_dilution_series_SPEC_vs_InSol\SPEC\5ng\report.parquet')
spec_20ng = pd.read_parquet(r'Z:\Tim_SPEC\K562_dilution_series_SPEC_vs_InSol\SPEC\20ng\report.parquet')
spec_50ng = pd.read_parquet(r'Z:\Tim_SPEC\K562_dilution_series_SPEC_vs_InSol\SPEC\50ng\report.parquet')
spec_200ng = pd.read_parquet(r'Z:\Tim_SPEC\K562_dilution_series_SPEC_vs_InSol\SPEC\200ng\report.parquet')
spec_500ng = pd.read_parquet(r'Z:\Tim_SPEC\K562_dilution_series_SPEC_vs_InSol\SPEC\500ng\report.parquet')
spec_1000ng = pd.read_parquet(r'Z:\Tim_SPEC\K562_dilution_series_SPEC_vs_InSol\SPEC\1000ng\report.parquet')
####
insol_0p25ng = pd.read_parquet(r'Z:\Tim_SPEC\K562_dilution_series_SPEC_vs_InSol\InSol\0p25ng\report.parquet')
insol_1ng = pd.read_parquet(r'Z:\Tim_SPEC\K562_dilution_series_SPEC_vs_InSol\InSol\1ng\report.parquet')
insol_5ng = pd.read_parquet(r'Z:\Tim_SPEC\K562_dilution_series_SPEC_vs_InSol\InSol\5ng\report.parquet')
insol_20ng = pd.read_parquet(r'Z:\Tim_SPEC\K562_dilution_series_SPEC_vs_InSol\InSol\20ng\report.parquet')
insol_50ng = pd.read_parquet(r'Z:\Tim_SPEC\K562_dilution_series_SPEC_vs_InSol\InSol\50ng\report.parquet')
insol_200ng = pd.read_parquet(r'Z:\Tim_SPEC\K562_dilution_series_SPEC_vs_InSol\InSol\200ng\report.parquet')
insol_500ng = pd.read_parquet(r'Z:\Tim_SPEC\K562_dilution_series_SPEC_vs_InSol\InSol\500ng\report.parquet')
insol_1000ng = pd.read_parquet(r'Z:\Tim_SPEC\K562_dilution_series_SPEC_vs_InSol\InSol\1000ng\report.parquet')
####
pac_0p25ng = pd.read_parquet(r'Z:\Tim_SPEC\K562_dilution_series_SPEC_vs_InSol\PAC\0p25ng\report.parquet')
pac_1ng = pd.read_parquet(r'Z:\Tim_SPEC\K562_dilution_series_SPEC_vs_InSol\PAC\1ng\report.parquet')
pac_5ng = pd.read_parquet(r'Z:\Tim_SPEC\K562_dilution_series_SPEC_vs_InSol\PAC\5ng\report.parquet')
pac_20ng = pd.read_parquet(r'Z:\Tim_SPEC\K562_dilution_series_SPEC_vs_InSol\PAC\20ng\report.parquet')
pac_50ng = pd.read_parquet(r'Z:\Tim_SPEC\K562_dilution_series_SPEC_vs_InSol\PAC\50ng\report.parquet')
pac_200ng = pd.read_parquet(r'Z:\Tim_SPEC\K562_dilution_series_SPEC_vs_InSol\PAC\200ng\report.parquet')
pac_500ng = pd.read_parquet(r'Z:\Tim_SPEC\K562_dilution_series_SPEC_vs_InSol\PAC\500ng\report.parquet')
pac_1000ng = pd.read_parquet(r'Z:\Tim_SPEC\K562_dilution_series_SPEC_vs_InSol\PAC\1000ng\report.parquet')

# %%
list_spec = [spec_0p25ng, spec_1ng, spec_5ng, spec_20ng, spec_50ng, spec_200ng, spec_500ng, spec_1000ng]
list_insol = [insol_0p25ng, insol_1ng, insol_5ng, insol_20ng, insol_50ng, insol_200ng, insol_500ng, insol_1000ng]
list_pac = [pac_0p25ng, pac_1ng, pac_5ng, pac_20ng, pac_50ng, pac_200ng, pac_500ng, pac_1000ng]

# %%
tmp_df_list_pg_spec = []
tmp_df_list_prec_spec = []
for el in list_spec:
    tmp_df = el[el['PG.Q.Value']< 0.01]
    tmp_df1 = pd.pivot_table(tmp_df, columns = 'Run', index = 'Protein.Group', values= 'PG.MaxLFQ')
    tmp_df_list_pg_spec.append(tmp_df1)
    tmp_df2 = pd.pivot_table(tmp_df, columns = 'Run', index = 'Precursor.Id', values= 'Precursor.Normalised')
    tmp_df_list_prec_spec.append(tmp_df2)


#####
tmp_df_list_pg_insol = []
tmp_df_list_prec_insol = []
for el in list_insol:
    tmp_df = el[el['PG.Q.Value']< 0.01]
    tmp_df1 = pd.pivot_table(tmp_df, columns = 'Run', index = 'Protein.Group', values= 'PG.MaxLFQ')
    tmp_df_list_pg_insol.append(tmp_df1)
    tmp_df2 = pd.pivot_table(tmp_df, columns = 'Run', index = 'Precursor.Id', values= 'Precursor.Normalised')
    tmp_df_list_prec_insol.append(tmp_df2)

#####
tmp_df_list_pg_pac = []
tmp_df_list_prec_pac = []
for el in list_pac:
    tmp_df = el[el['PG.Q.Value']< 0.01]
    tmp_df1 = pd.pivot_table(tmp_df, columns = 'Run', index = 'Protein.Group', values= 'PG.MaxLFQ')
    tmp_df_list_pg_pac.append(tmp_df1)
    tmp_df2 = pd.pivot_table(tmp_df, columns = 'Run', index = 'Precursor.Id', values= 'Precursor.Normalised')
    tmp_df_list_prec_pac.append(tmp_df2)

# %%
cv_list_pg_spec = []
for df in tmp_df_list_pg_spec:
    linear_values = df.iloc[:,:4]

    n_valid = linear_values.notna().sum(axis=1)
    
    cv = linear_values.std(axis=1) / linear_values.mean(axis=1)
    cv = cv.replace(0, np.nan)

    cv[n_valid < 2] = np.nan
    
    cv_list_pg_spec.append(cv)

cv_list_prec_spec = []
for df in tmp_df_list_prec_spec:
    linear_values = df.iloc[:,:4]

    n_valid = linear_values.notna().sum(axis=1)
    
    cv = linear_values.std(axis=1) / linear_values.mean(axis=1)
    cv = cv.replace(0, np.nan)

    cv[n_valid < 2] = np.nan
    
    cv_list_prec_spec.append(cv)

# %%
cv_list_pg_insol = []
for df in tmp_df_list_pg_insol:
    linear_values = df.iloc[:,:4]

    n_valid = linear_values.notna().sum(axis=1)
    
    cv = linear_values.std(axis=1) / linear_values.mean(axis=1)
    cv = cv.replace(0, np.nan)

    cv[n_valid < 2] = np.nan
    
    cv_list_pg_insol.append(cv)

cv_list_prec_insol = []
for df in tmp_df_list_prec_spec:
    linear_values = df.iloc[:,:4]

    n_valid = linear_values.notna().sum(axis=1)
    
    cv = linear_values.std(axis=1) / linear_values.mean(axis=1)
    cv = cv.replace(0, np.nan)

    cv[n_valid < 2] = np.nan
    
    cv_list_prec_insol.append(cv)

# %%
cv_list_pg_pac = []
for df in tmp_df_list_pg_pac:
    linear_values = df.iloc[:,:4]

    n_valid = linear_values.notna().sum(axis=1)
    
    cv = linear_values.std(axis=1) / linear_values.mean(axis=1)
    cv = cv.replace(0, np.nan)

    cv[n_valid < 2] = np.nan
    
    cv_list_pg_pac.append(cv)

cv_list_prec_pac = []
for df in tmp_df_list_prec_spec:
    linear_values = df.iloc[:,:4]

    n_valid = linear_values.notna().sum(axis=1)
    
    cv = linear_values.std(axis=1) / linear_values.mean(axis=1)
    cv = cv.replace(0, np.nan)

    cv[n_valid < 2] = np.nan
    
    cv_list_prec_pac.append(cv)

# %%
color_palette_red = ['#EEA69B', '#E78373', '#E1604C', '#DB452E', '#B3321E', '#8C2718', '#641C11', '#25000e']
color_palette_violet = ["#fcb0f3","#dc94ef","#bc77ec","#9d5be8","#7d3ee4","#5d22e1","#3d05dd", '#382c83']
color_palette_orange = ["#ffe169","#fad643","#edc531","#dbb42c","#b69121","#a47e1b","#926c15", '#6b4f10']

# %%
fig = go.Figure()
for i, el in enumerate(cv_list_pg_spec):
    fig.add_trace(go.Violin(y = el, marker_color = color_palette_red[i], points = False,box_visible=True))
    fig.add_trace(go.Violin(y = cv_list_pg_pac[i], marker_color = color_palette_violet[i], points = False, box_visible=True))
    fig.add_trace(go.Violin(y = cv_list_pg_insol[i], marker_color = color_palette_orange[i], points = False, box_visible=True))
fig.update_layout(width = 1000, height = 600, showlegend = False, template = 'plotly_white')

fig.write_image(r'D:\Projects\SPEC\figs_raw\Suppl_Figure1a.pdf', width = 1000, height = 600)

# %%
fig = go.Figure()
for i, el in enumerate(cv_list_prec_spec):
    fig.add_trace(go.Violin(y = el, marker_color = color_palette_red[i], points = False,box_visible=True))
    fig.add_trace(go.Violin(y = cv_list_prec_pac[i], marker_color = color_palette_violet[i], points = False, box_visible=True))
    fig.add_trace(go.Violin(y = cv_list_prec_insol[i], marker_color = color_palette_orange[i], points = False, box_visible=True))
fig.update_layout(width = 1000, height = 600, showlegend = False, template = 'plotly_white')
fig.write_image(r'D:\Projects\SPEC\figs_raw\Suppl_Figure1b.pdf', width = 1000, height = 600)

# %% [markdown]
# # Supplemendary Figure 1D

# %%
path_used = r'Z:\Tim_SPEC\figure2\K562_dilution_series_SPEC_vs_InSol'

experiment_dict = [
    {'instrument': '0.25 ng', 'method' : 'In sol', 'file_tags': ['A1', 'A2', 'A3', 'A4'], 'path': r'Z:\Tim_SPEC\figure2\K562_dilution_series_SPEC_vs_InSol\InSol\0p25ng\report.parquet'},
    {'instrument': '1 ng', 'method' : 'In sol', 'file_tags': ['B1', 'B2', 'B3', 'B4'], 'path': r'Z:\Tim_SPEC\figure2\K562_dilution_series_SPEC_vs_InSol\InSol\1ng\report.parquet'},
    {'instrument': '5 ng', 'method' : 'In sol', 'file_tags': ['C1', 'C2', 'C3', 'C4'], 'path': r'Z:\Tim_SPEC\figure2\K562_dilution_series_SPEC_vs_InSol\InSol\5ng\report.parquet'},
    {'instrument': '20 ng', 'method' : 'In sol', 'file_tags': ['D1', 'D2', 'D3', 'D4'], 'path': r'Z:\Tim_SPEC\figure2\K562_dilution_series_SPEC_vs_InSol\InSol\20ng\report.parquet'},
    {'instrument': '50 ng', 'method' : 'In sol', 'file_tags': ['E1', 'E2', 'E3', 'E4'], 'path': r'Z:\Tim_SPEC\figure2\K562_dilution_series_SPEC_vs_InSol\InSol\50ng\report.parquet'},
    {'instrument': '200 ng', 'method' : 'In sol', 'file_tags': ['F1', 'F2', 'F3', 'F4'], 'path': r'Z:\Tim_SPEC\figure2\K562_dilution_series_SPEC_vs_InSol\InSol\200ng\report.parquet'},
    {'instrument': '500 ng', 'method' : 'In sol', 'file_tags': ['G1', 'G2', 'G3', 'G4'], 'path': r'Z:\Tim_SPEC\figure2\K562_dilution_series_SPEC_vs_InSol\InSol\500ng\report.parquet'},
    {'instrument': '1000 ng', 'method' : 'In sol', 'file_tags': ['H1', 'H2', 'H3', 'H4'], 'path': r'Z:\Tim_SPEC\figure2\K562_dilution_series_SPEC_vs_InSol\InSol\1000ng\report.parquet'},
    {'instrument': '0.25 ng', 'method' : 'PAC', 'file_tags': ['A9', 'A10', 'A11', 'A12'], 'path': r'Z:\Tim_SPEC\figure2\K562_dilution_series_SPEC_vs_InSol\PAC\0p25ng\report.parquet'},
    {'instrument': '1 ng', 'method' : 'PAC', 'file_tags': ['B9', 'B10', 'B11', 'B12'], 'path': r'Z:\Tim_SPEC\figure2\K562_dilution_series_SPEC_vs_InSol\PAC\1ng\report.parquet'},
    {'instrument': '5 ng', 'method' : 'PAC', 'file_tags': ['C9', 'C10', 'C11', 'C12'], 'path': r'Z:\Tim_SPEC\figure2\K562_dilution_series_SPEC_vs_InSol\PAC\5ng\report.parquet'},
    {'instrument': '20 ng', 'method' : 'PAC', 'file_tags': ['D9', 'D10', 'D11', 'D12'], 'path': r'Z:\Tim_SPEC\figure2\K562_dilution_series_SPEC_vs_InSol\PAC\20ng\report.parquet'},
    {'instrument': '50 ng', 'method' : 'PAC', 'file_tags': ['E9', 'E10', 'E11', 'E12'], 'path': r'Z:\Tim_SPEC\figure2\K562_dilution_series_SPEC_vs_InSol\PAC\50ng\report.parquet'},
    {'instrument': '200 ng', 'method' : 'PAC', 'file_tags': ['F9', 'F10', 'F11', 'F12'], 'path': r'Z:\Tim_SPEC\figure2\K562_dilution_series_SPEC_vs_InSol\PAC\200ng\report.parquet'},
    {'instrument': '500 ng', 'method' : 'PAC', 'file_tags': ['G9', 'G10', 'G11', 'G12'], 'path': r'Z:\Tim_SPEC\figure2\K562_dilution_series_SPEC_vs_InSol\PAC\500ng\report.parquet'},
    {'instrument': '1000 ng', 'method' : 'PAC', 'file_tags': ['H9', 'H10', 'H11', 'H12'], 'path': r'Z:\Tim_SPEC\figure2\K562_dilution_series_SPEC_vs_InSol\PAC\1000ng\report.parquet'},
    {'instrument': '0.25 ng', 'method' : 'SPEC', 'file_tags': ['A5', 'A6', 'A7', 'A8'], 'path': r'Z:\Tim_SPEC\figure2\K562_dilution_series_SPEC_vs_InSol\SPEC\0p25ng\report.parquet'},
    {'instrument': '1 ng', 'method' : 'SPEC', 'file_tags': ['B5', 'B6', 'B7', 'B8'], 'path': r'Z:\Tim_SPEC\figure2\K562_dilution_series_SPEC_vs_InSol\SPEC\1ng\report.parquet'},
    {'instrument': '5 ng', 'method' : 'SPEC', 'file_tags': ['C5', 'C6', 'C7', 'C8'], 'path': r'Z:\Tim_SPEC\figure2\K562_dilution_series_SPEC_vs_InSol\SPEC\5ng\report.parquet'},
    {'instrument': '20 ng', 'method' : 'SPEC', 'file_tags': ['D5', 'D6', 'D7', 'D8'], 'path': r'Z:\Tim_SPEC\figure2\K562_dilution_series_SPEC_vs_InSol\SPEC\20ng\report.parquet'},
    {'instrument': '50 ng', 'method' : 'SPEC', 'file_tags': ['E5', 'E6', 'E7', 'E8'], 'path': r'Z:\Tim_SPEC\figure2\K562_dilution_series_SPEC_vs_InSol\SPEC\50ng\report.parquet'},
    {'instrument': '200 ng', 'method' : 'SPEC', 'file_tags': ['F5', 'F6', 'F7', 'F8'], 'path': r'Z:\Tim_SPEC\figure2\K562_dilution_series_SPEC_vs_InSol\SPEC\200ng\report.parquet'},
    {'instrument': '500 ng', 'method' : 'SPEC', 'file_tags': ['G5', 'G6', 'G7', 'G8'], 'path': r'Z:\Tim_SPEC\figure2\K562_dilution_series_SPEC_vs_InSol\SPEC\500ng\report.parquet'},
    {'instrument': '1000 ng', 'method' : 'SPEC', 'file_tags': ['H5', 'H6', 'H7', 'H8'], 'path': r'Z:\Tim_SPEC\figure2\K562_dilution_series_SPEC_vs_InSol\SPEC\1000ng\report.parquet'},
]

# %%
from collections import defaultdict

# Group experiments by file
experiments_by_file = defaultdict(list)
for exp in experiment_dict:
    experiments_by_file[exp['path']].append(exp)

# Process
agg_stat_df = []
for path, experiments in experiments_by_file.items():
    df_full = cf.load_parquet_cached(path)
    df_full = df_full[df_full['PG.Q.Value'] < 0.01]
    
    for experiment in experiments:
        _df_agg = cf.process_experiment(
            df_full, 
            experiment, 
            protease='trypsin',
            max_missed_cleavages=2
        )
        agg_stat_df.append(_df_agg)

df = pd.concat(agg_stat_df, ignore_index=True)
# Out:
# d:\Projects\SPEC\scripts_for_figs\SPEC-figures\helper_functions.py:44: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   mc_per_run = _df.groupby('Run').apply(calculate_mc_per_run).reset_index()
# d:\Projects\SPEC\scripts_for_figs\SPEC-figures\helper_functions.py:44: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   mc_per_run = _df.groupby('Run').apply(calculate_mc_per_run).reset_index()
# ...

# %%
df.head()
# Out:
#                                                  Run  peptide  precursor  \
# 0  20250407_OA4_Evo15_2p25min_DeOl_InSol_5min_dig...     4927       5388
# 1  20250407_OA4_Evo15_2p25min_DeOl_InSol_5min_dig...     4792       5215
# 2  20250407_OA4_Evo15_2p25min_DeOl_InSol_5min_dig...     5823       6400
# 3  20250407_OA4_Evo15_2p25min_DeOl_InSol_10min_di...     4693       5104
# 4  20250407_OA4_Evo15_2p25min_DeOl_InSol_10min_di...     5737       6336
#
#    protein  total_intensity       MC0       MC1  MC2    avg_MC  PG20  Pr20  \
# 0     1848     1.937499e+09  0.580025  0.419975  0.0  0.419975   771  1114
# 1     1673     1.962324e+09  0.603127  0.396873  0.0  0.396873   771  1114
# 2     1917     2.320125e+09  0.585989  0.414011  0.0  0.414011   771  1114
# 3     1860     1.257719e+09  0.660839  0.339161  0.0  0.339161  1018  1253
# 4     2013     3.721026e+09  0.585832  0.414168  0.0  0.414168  1018  1253
#
#    total_peptides  total_protein_groups  total_precursors instrument  \
# ...

# %%
input_list = df['instrument'].unique().tolist()

# %%
df_insol = df[df['method'] == 'In sol']
df_SPEC = df[df['method'] == 'SPEC']
df_PAC = df[df['method'] == 'PAC']

# %%
fin_insol = []
for el in input_list:
    tmp_df = df_insol[df_insol['instrument'] == el]
    fin_insol.append(tmp_df['PG20'].tolist()) 


flattened_insol = [item for sublist in fin_insol for item in sublist]
input_list1 = np.repeat(input_list, 4).tolist()
df_insol = pd.DataFrame({'Selectivity':flattened_insol, 'ID':input_list1})

# %%
fin_SPEC = []
for el in input_list:
    tmp_df = df_SPEC[df_SPEC['instrument'] == el]
    fin_SPEC.append(tmp_df['PG20'].tolist()) 
flattened_SPEC = [item for sublist in fin_SPEC for item in sublist]
input_list1 = np.repeat(input_list, 4).tolist()
df_SPEC = pd.DataFrame({'Selectivity':flattened_SPEC, 'ID':input_list1})

# %%
fin_PAC = []
for el in input_list:
    tmp_df = df_PAC[df_PAC['instrument'] == el]
    fin_PAC.append(tmp_df['PG20'].tolist()) 
flattened_PAC = [item for sublist in fin_PAC for item in sublist]
input_list1 = np.repeat(input_list, 4).tolist()
df_PAC = pd.DataFrame({'Selectivity':flattened_PAC, 'ID':input_list1})

# %%
fig = px.strip(df_SPEC, y='Selectivity', x='ID', orientation='h')

fig.add_scatter(
    y=df_insol['Selectivity'], 
    x=df_insol['ID'],
    mode='markers',
    marker=dict(size=14, color=' #faa307', line=dict(width=0.5, color='black')),
    name='df_insol'
)

fig.add_scatter(
    y=df_PAC['Selectivity'], 
    x=df_PAC['ID'],
    mode='markers',
    marker=dict(size=14, color='#6D25AD', line=dict(width=0.5, color='black')),
    name='df_PAC' 
)

fig.update_layout(width=600, height=600, template='plotly_white', showlegend=False)


fig.update_traces(
    marker=dict(size=14, color='#db4c2e', line=dict(width=0.5, color='black')),
    selector=dict(type='box')  
)


fig.update_yaxes(
    range=[0, 10100],
    showgrid=True,
    gridwidth=0.1,           
    gridcolor='#F3F2F2',  
    griddash='solid',
    title='Selectivity (%)'  
)

fig.update_xaxes(
    title='Sample ID' 
)

fig.show()
#fig.write_image(r'D:\Projects\SPEC\figs_raw\Suppl_Figure1d.pdf', width = 600, height = 600)

# %% [markdown]
# # Supplementary Figure 1E

# %%
df_insol = df[df['method'] == 'In sol']
df_SPEC = df[df['method'] == 'SPEC']
df_PAC = df[df['method'] == 'PAC']

# %%
fin_insol = []
for el in input_list:
    tmp_df = df_insol[df_insol['instrument'] == el]
    fin_insol.append(np.log2(tmp_df['total_intensity']).tolist()) 


flattened_insol = [item for sublist in fin_insol for item in sublist]
input_list1 = np.repeat(input_list, 4).tolist()
df_insol = pd.DataFrame({'Selectivity':flattened_insol, 'ID':input_list1})

# %%
fin_SPEC = []
for el in input_list:
    tmp_df = df_SPEC[df_SPEC['instrument'] == el]
    fin_SPEC.append(np.log2(tmp_df['total_intensity']).tolist()) 
flattened_SPEC = [item for sublist in fin_SPEC for item in sublist]
input_list1 = np.repeat(input_list, 4).tolist()
df_SPEC = pd.DataFrame({'Selectivity':flattened_SPEC, 'ID':input_list1})

# %%
fin_PAC = []
for el in input_list:
    tmp_df = df_PAC[df_PAC['instrument'] == el]
    fin_PAC.append(np.log2(tmp_df['total_intensity']).tolist()) 
flattened_PAC = [item for sublist in fin_PAC for item in sublist]
input_list1 = np.repeat(input_list, 4).tolist()
df_PAC = pd.DataFrame({'Selectivity':flattened_PAC, 'ID':input_list1})

# %%
df_PAC.head()
# Out:
#    Selectivity       ID
# 0    36.133770  0.25 ng
# 1    36.975315  0.25 ng
# 2    36.486179  0.25 ng
# 3    35.616077  0.25 ng
# 4    36.274860     1 ng

# %%
fig = px.strip(df_SPEC, y='Selectivity', x='ID', orientation='h')

fig.add_scatter(
    y=df_insol['Selectivity'], 
    x=df_insol['ID'],
    mode='markers',
    marker=dict(size=14, color=' #faa307', line=dict(width=0.5, color='black')),
    name='df_insol'
)

fig.add_scatter(
    y=df_PAC['Selectivity'], 
    x=df_PAC['ID'],
    mode='markers',
    marker=dict(size=14, color='#6D25AD', line=dict(width=0.5, color='black')),
    name='df_PAC' 
)

fig.update_layout(width=600, height=600, template='plotly_white', showlegend=False)


fig.update_traces(
    marker=dict(size=14, color='#db4c2e', line=dict(width=0.5, color='black')),
    selector=dict(type='box')  
)


fig.update_yaxes(
    range=[34, 44],
    showgrid=True,
    gridwidth=0.1,           
    gridcolor='#F3F2F2',  
    griddash='solid',
    title='Selectivity (%)'  
)

fig.update_xaxes(
    title='Sample ID' 
)

fig.show()
fig.write_image(r'D:\Projects\SPEC\figs_raw\Suppl_Figure1e.pdf', width = 600, height = 600)

# %% [markdown]
# # Supplementary figure 1F

# %%
tags1 = cf.generate_pattern_list(['D'], 1, 4, 'E178_')
tags2 = cf.generate_pattern_list(['C'], 1, 4, 'E178_')
tags7 = cf.generate_pattern_list(['E'], 1, 4, 'E178_')
tags9 = cf.generate_pattern_list(['A'], 1, 4, 'E178_')
experiment_dict = [
    {'instrument': 'No detergent', 'method' : 'In sol', 'file_tags': tags1, 'path': r'Z:\Tim_SPEC\figure1\spec_vs_insol+detergents.parquet'},
    {'instrument': 'No detergent', 'method' : 'SAX', 'file_tags': tags9, 'path': r'Z:\Tim_SPEC\figure1\spec_vs_insol+detergents.parquet'},
    {'instrument': 'No detergent', 'method' : 'SCX', 'file_tags': tags7, 'path': r'Z:\Tim_SPEC\figure1\spec_vs_insol+detergents.parquet'},
    {'instrument': 'No detergent', 'method' : 'C18', 'file_tags': tags2, 'path': r'Z:\Tim_SPEC\figure1\spec_vs_insol+detergents.parquet'},
]

# %%
from collections import defaultdict

# Group experiments by file
experiments_by_file = defaultdict(list)
for exp in experiment_dict:
    experiments_by_file[exp['path']].append(exp)

# Process
agg_stat_df = []
for path, experiments in experiments_by_file.items():
    df_full = cf.load_parquet_cached(path)
    df_full = df_full[df_full['PG.Q.Value'] < 0.01]
    
    for experiment in experiments:
        _df_agg = cf.process_experiment(
            df_full, 
            experiment, 
            protease='trypsin',
            max_missed_cleavages=2
        )
        agg_stat_df.append(_df_agg)

df = pd.concat(agg_stat_df, ignore_index=True)
# Out:
# d:\Projects\SPEC\scripts_for_figs\SPEC-figures\helper_functions.py:44: FutureWarning:
#
# DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#
# d:\Projects\SPEC\scripts_for_figs\SPEC-figures\helper_functions.py:44: FutureWarning:
#
# DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#
# d:\Projects\SPEC\scripts_for_figs\SPEC-figures\helper_functions.py:44: FutureWarning:
#
# ...

# %%
methods = df['method'].unique().tolist()
fin = []
for el in methods:
    tmp_df = df[df['method'] == el]
    fin.append(np.log2(tmp_df['total_intensity']).tolist()) 

fin = [fin[-1], fin[0], fin[2], fin[1]]

# %%
color_palette = ['#206d46', '#6D25AD','#2576AD', '#db4c2e']

# %%
fig = go.Figure()
for i, el in enumerate(fin):
    fig.add_trace(go.Box(y = el, boxpoints='all', pointpos=0, marker_color = color_palette[i], marker=dict(size=12, line = dict(width = 0.5))))
fig.update_layout(width = 600, height = 600, template = 'none', showlegend = False)
fig.update_yaxes(range = [29.9,45])
fig.write_image(r'D:\Projects\SPEC\figs_raw\Suppl_Figure1f.pdf', width = 600, height = 600)

# %% [markdown]
# # Supplementary figure 1G

# %%
mouse_FFPE_SPEC_Liver = cf.generate_pattern_list(['A'], 1, 4, 'E170_')
mouse_FFPE_SPEC_Brain = cf.generate_pattern_list(['B'], 1, 4, 'E170_')
mouse_FFPE_SPEC_Heart = cf.generate_pattern_list(['C'], 1, 4, 'E170_')
mouse_FFPE_SPEC_Kidney = cf.generate_pattern_list(['D'], 1, 4, 'E170_')
mouse_FFPE_SPEC_Testis = cf.generate_pattern_list(['E'], 1, 4, 'E170_')
mouse_FFPE_SPEC_Lung = cf.generate_pattern_list(['F'], 1, 4, 'E170_')
mouse_FFPE_PAC_Liver = cf.generate_pattern_list(['A'], 9, 12, 'E170_')
mouse_FFPE_PAC_Brain = cf.generate_pattern_list(['B'], 9, 12, 'E170_')
mouse_FFPE_PAC_Heart = cf.generate_pattern_list(['C'], 9, 12, 'E170_')
mouse_FFPE_PAC_Kidney = cf.generate_pattern_list(['D'], 9, 12, 'E170_')
mouse_FFPE_PAC_Testis = cf.generate_pattern_list(['E'], 9, 12, 'E170_')
mouse_FFPE_PAC_Lung = cf.generate_pattern_list(['F'], 9, 12, 'E170_')
tags_all_mouse_FFPE = cf.generate_pattern_list(['A','B','C','D','E','F'], 1, 4, 'E170_')

# %%
experiment_dict = [
    {'instrument': 'SPEC', 'method': 'Lung',
     'file_tags': mouse_FFPE_SPEC_Lung,
     'path': r'Z:\Tim_SPEC\figure3\tissues_SPECvsPAC\H032_E170.parquet'},
     {'instrument': 'PAC', 'method': 'Lung',
     'file_tags': mouse_FFPE_PAC_Lung,
     'path': r'Z:\Tim_SPEC\figure3\tissues_SPECvsPAC\H032_E170.parquet'},
     {'instrument': 'SPEC', 'method': 'Heart',
     'file_tags': mouse_FFPE_SPEC_Heart,
     'path': r'Z:\Tim_SPEC\figure3\tissues_SPECvsPAC\H032_E170.parquet'},
     {'instrument': 'PAC', 'method': 'Heart',
     'file_tags': mouse_FFPE_PAC_Heart,
     'path': r'Z:\Tim_SPEC\figure3\tissues_SPECvsPAC\H032_E170.parquet'},
     {'instrument': 'SPEC', 'method': 'Kidney',
     'file_tags': mouse_FFPE_SPEC_Kidney,
     'path': r'Z:\Tim_SPEC\figure3\tissues_SPECvsPAC\H032_E170.parquet'},
     {'instrument': 'PAC', 'method': 'Kidney',
     'file_tags': mouse_FFPE_PAC_Kidney,
     'path': r'Z:\Tim_SPEC\figure3\tissues_SPECvsPAC\H032_E170.parquet'},
     {'instrument': 'SPEC', 'method': 'Brain',
     'file_tags': mouse_FFPE_SPEC_Brain,
     'path': r'Z:\Tim_SPEC\figure3\tissues_SPECvsPAC\H032_E170.parquet'},
     {'instrument': 'PAC', 'method': 'Brain',
     'file_tags': mouse_FFPE_PAC_Brain,
     'path': r'Z:\Tim_SPEC\figure3\tissues_SPECvsPAC\H032_E170.parquet'},
    {'instrument': 'SPEC', 'method': 'Liver',
     'file_tags': mouse_FFPE_SPEC_Liver,
     'path': r'Z:\Tim_SPEC\figure3\tissues_SPECvsPAC\H032_E170.parquet'},
     {'instrument': 'PAC', 'method': 'Liver',
     'file_tags': mouse_FFPE_PAC_Liver,
     'path': r'Z:\Tim_SPEC\figure3\tissues_SPECvsPAC\H032_E170.parquet'},
     {'instrument': 'SPEC', 'method': 'Testis',
     'file_tags': mouse_FFPE_SPEC_Testis,
     'path': r'Z:\Tim_SPEC\figure3\tissues_SPECvsPAC\H032_E170.parquet'},
     {'instrument': 'PAC', 'method': 'Testis',
     'file_tags': mouse_FFPE_PAC_Testis,
     'path': r'Z:\Tim_SPEC\figure3\tissues_SPECvsPAC\H032_E170.parquet'},
]

# %%
from collections import defaultdict

# Group experiments by file
experiments_by_file = defaultdict(list)
for exp in experiment_dict:
    experiments_by_file[exp['path']].append(exp)

# Process
agg_stat_df = []
for path, experiments in experiments_by_file.items():
    df_full = cf.load_parquet_cached(path)
    df_full = df_full[df_full['PG.Q.Value'] < 0.01]
    
    for experiment in experiments:
        _df_agg = cf.process_experiment(
            df_full, 
            experiment, 
            protease='trypsin',
            max_missed_cleavages=2
        )
        agg_stat_df.append(_df_agg)

df = pd.concat(agg_stat_df, ignore_index=True)

# %%
df['method'].unique()
# Out:
# array(['Lung', 'Heart', 'Kidney', 'Brain', 'Liver', 'Testis'],
#       dtype=object)

# %%
df['instrument'].unique()
# Out:
# array(['SPEC', 'PAC'], dtype=object)

# %%
df['tissueID'] = df['method'] + '_' + df['instrument']

# %%
methods = ['Testis_PAC', 'Testis_SPEC', 'Liver_PAC', 'Liver_SPEC', 'Brain_PAC', 'Brain_SPEC', 'Kidney_PAC', 'Kidney_SPEC', 'Heart_PAC', 'Heart_SPEC', 'Lung_PAC', 'Lung_SPEC']
fin = []
for el in methods:
    tmp_df = df[df['tissueID'] == el]
    fin.append(np.log2(tmp_df['total_intensity']).tolist())

# %%
fin
# Out:
# [[38.488826751708984, 38.77128219604492, 38.22711181640625, 38.03803253173828],
#  [37.22223663330078,
#   37.23322296142578,
#   38.163597106933594,
#   37.528663635253906],
#  [38.52674865722656, 39.14003372192383, 38.987247467041016],
#  [37.72551345825195, 37.4055061340332, 37.605770111083984, 38.183990478515625],
#  [38.73825454711914, 38.54690933227539, 38.48562240600586, 38.60056686401367],
#  [37.84377670288086, 37.43421173095703, 36.99050521850586, 38.18037033081055],
#  [38.75925064086914, 39.527103424072266, 39.183372497558594],
#  [37.58491897583008, 38.32463836669922, 37.36766052246094, 38.70817947387695],
#  [39.07497024536133, 39.15139389038086, 38.00801086425781, 38.80573654174805],
#  [38.21937561035156, 37.53995132446289, 37.929649353027344, 38.07390594482422],
#  [37.965797424316406,
#   37.506622314453125,
#   38.76113510131836,
#   37.61699295043945],
#  [37.4040412902832, 37.41616439819336, 37.269081115722656, 37.96883773803711]]

# %%
color_palette = ['#623a73', '#ff0000']
fig = go.Figure()
for i, el in enumerate(fin):
    fig.add_trace(go.Box(y = el, boxpoints='all', pointpos=0, marker_color = color_palette[i%2], marker=dict(size=12, line = dict(width = 0.5))))
fig.update_layout(width = 1000, height = 600, template = 'none', showlegend = False)
fig.update_yaxes(range = [35,40.1])
fig.write_image(r'D:\Projects\SPEC\figs_raw\Suppl_Figure1g.pdf', width = 1000, height = 600)

# %% [markdown]
# # Supplementary Figure 1H

# %%
df = pd.read_parquet(r'Z:\Tim_SPEC\supplements\plasma_normal_proteome.parquet')

# %%
df.head()
# Out:
#    Run.Index                                                Run Channel  \
# 0          1  20251205_OA4_Eno12_12p95_min_TiHe_SA_H032_E237_A2
# 1          2  20251205_OA4_Eno12_12p95_min_TiHe_SA_H032_E237_A3
# 2          3  20251205_OA4_Eno12_12p95_min_TiHe_SA_H032_E237_A4
# 3          4  20251205_OA4_Eno12_12p95_min_TiHe_SA_H032_E237_A5
# 4          5  20251205_OA4_Eno12_12p95_min_TiHe_SA_H032_E237_A6
#
#            Precursor.Id    Modified.Sequence Stripped.Sequence  \
# 0  (UniMod:1)AALASSLIR2  (UniMod:1)AALASSLIR         AALASSLIR
# 1  (UniMod:1)AALASSLIR2  (UniMod:1)AALASSLIR         AALASSLIR
# 2  (UniMod:1)AALASSLIR2  (UniMod:1)AALASSLIR         AALASSLIR
# 3  (UniMod:1)AALASSLIR2  (UniMod:1)AALASSLIR         AALASSLIR
# 4  (UniMod:1)AALASSLIR2  (UniMod:1)AALASSLIR         AALASSLIR
#
#    Precursor.Charge  Precursor.Lib.Index  Decoy  Proteotypic  ...  \
# 0                 2                    0      0            0  ...
# ...

# %%
df = df[df['PG.Q.Value']<0.01]

# %%
df['reduced_id'] = df['Run'].apply(lambda x: x.split('_')[-1])

# %%
labels = [['A1', 'A2', 'A3', 'A4', 'A5', 'A6', 'A7', 'A8'],['C1', 'C2', 'C3', 'C4', 'C5', 'C6', 'C7', 'C8']]

# %%
labels = [['A1', 'A2', 'A3', 'A4', 'A5', 'A6', 'A7', 'A8'],['C1', 'C2', 'C3', 'C4', 'C5', 'C6', 'C7', 'C8']]

# %%
df_pivot_neat = pd.pivot_table(df[df['reduced_id'].isin(labels[0])], values = 'PG.MaxLFQ', index = 'Protein.Group', columns = 'reduced_id')
df_pivot_spec = pd.pivot_table(df[df['reduced_id'].isin(labels[1])], values = 'PG.MaxLFQ', index = 'Protein.Group', columns = 'reduced_id')

# %%
nums_neat = []
for col in df_pivot_neat.columns:
    nums_neat.append(len(df_pivot_neat[col].dropna()))

nums_spec = []
for col in df_pivot_spec.columns:
    nums_spec.append(len(df_pivot_spec[col].dropna()))

nums_all = [nums_neat] + [nums_spec]

# %%
color_palette = ['#623a73', '#ff0000']
fig = go.Figure()
for i, el in enumerate(nums_all):
    fig.add_trace(go.Box(y = el, boxpoints='all', pointpos=0, marker_color = color_palette[i%2], marker=dict(size=12, line = dict(width = 0.5))))
fig.update_layout(width = 600, height = 600, template = 'none', showlegend = False)
fig.update_yaxes(range = [0,2010])
fig.write_image(r'D:\Projects\SPEC\figs_raw\Suppl_Figure1i.pdf', width = 600, height = 600)

# %% [markdown]
# # Supplementary Figure 1J

# %%
df_pivot_neat = np.log10(df_pivot_neat).replace([np.inf, -np.inf], np.nan)
df_pivot_spec = np.log10(df_pivot_spec).replace([np.inf, -np.inf], np.nan)

# %%
df_pivot_neat['mean'] = df_pivot_neat.apply(np.mean, axis = 1)
df_pivot_spec['mean'] = df_pivot_spec.apply(np.mean, axis = 1)

# %%
merged = pd.merge(df_pivot_neat[['mean']], df_pivot_spec[['mean']], left_index=True, right_index=True, suffixes=('_neat', '_spec'))

# %%
from scipy.stats import gaussian_kde
from scipy.stats import gaussian_kde, pearsonr, spearmanr

# Calculate kernel density
x = merged['mean_neat']
y = merged['mean_spec']

# Remove any NaN or inf values
mask = np.isfinite(x) & np.isfinite(y)
x_clean = x[mask]
y_clean = y[mask]

# Calculate the point density
xy = np.vstack([x_clean, y_clean])
z = gaussian_kde(xy)(xy)


pearson_r, pearson_p = pearsonr(x_clean, y_clean)
spearman_r, spearman_p = spearmanr(x_clean, y_clean)

# Create figure with density coloring
fig = go.Figure()
fig.add_trace(go.Scatter(
    x=x_clean, 
    y=y_clean, 
    mode='markers',
    marker=dict(
        size=5,
        color=z,  # Color by density
        colorscale='inferno',  # Or 'Blues', 'Reds', 'Plasma', etc.
        showscale=True,
        colorbar=dict(title="Density"),
        line=dict(width=0)
    )
))

fig.update_layout(
    width=600, 
    height=600, 
    template='simple_white',
    xaxis_title='log10(mean_bulk)',
    yaxis_title='log10(mean_spec)'
)

fig.show()
fig.write_image(r'D:\Projects\SPEC\figs_raw\Suppl_Figure_1j.pdf', width=600, height=600)

# %% [markdown]
# # Figure 1K

# %%
tags9 = cf.generate_pattern_list(['A'], 1, 4, 'E178_')
tags10 = cf.generate_pattern_list(['A'], 5, 8, 'E178_')
tags11 = cf.generate_pattern_list(['A'], 9, 12, 'E178_')
experiment_dict = [
    {'instrument': 'No detergent', 'method' : 'SAX', 'file_tags': tags9, 'path': r'Z:\Tim_SPEC\figure1\spec_vs_insol+detergents.parquet'},
    {'instrument': '2 % SDS', 'method' : 'SAX', 'file_tags': tags10, 'path': r'Z:\Tim_SPEC\figure1\spec_vs_insol+detergents.parquet'},
    {'instrument': '2 % SDC', 'method' : 'SAX', 'file_tags': tags11, 'path': r'Z:\Tim_SPEC\figure1\spec_vs_insol+detergents.parquet'},
]

# %%
from collections import defaultdict

# Group experiments by file
experiments_by_file = defaultdict(list)
for exp in experiment_dict:
    experiments_by_file[exp['path']].append(exp)

# Process
agg_stat_df = []
for path, experiments in experiments_by_file.items():
    df_full = cf.load_parquet_cached(path)
    df_full = df_full[df_full['PG.Q.Value'] < 0.01]
    
    for experiment in experiments:
        _df_agg = cf.process_experiment(
            df_full, 
            experiment, 
            protease='trypsin',
            max_missed_cleavages=2
        )
        agg_stat_df.append(_df_agg)

df = pd.concat(agg_stat_df, ignore_index=True)
# Out:
# d:\Projects\SPEC\scripts_for_figs\SPEC-figures\helper_functions.py:44: FutureWarning:
#
# DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#
# d:\Projects\SPEC\scripts_for_figs\SPEC-figures\helper_functions.py:44: FutureWarning:
#
# DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#
# d:\Projects\SPEC\scripts_for_figs\SPEC-figures\helper_functions.py:44: FutureWarning:
#
# ...

# %%
df.head()
# Out:
#                                                 Run  peptide  precursor  \
# 0  20250524_OA4_Evo11_16p3_min_TiHe_SA_H032_E178_A1   180157     221291
# 1  20250524_OA4_Evo11_16p3_min_TiHe_SA_H032_E178_A2   179888     220779
# 2  20250524_OA4_Evo11_16p3_min_TiHe_SA_H032_E178_A3   177117     217044
# 3  20250524_OA4_Evo11_16p3_min_TiHe_SA_H032_E178_A4   174833     214348
# 4  20250524_OA4_Evo11_16p3_min_TiHe_SA_H032_E178_A5   104193     118559
#
#    protein  total_intensity       MC0       MC1       MC2    avg_MC  PG20  \
# 0     9043     2.937948e+12  0.745075  0.216229  0.038696  0.293621  8369
# 1     9102     2.892241e+12  0.747199  0.214878  0.037923  0.290724  8369
# 2     8969     2.198523e+12  0.741813  0.218959  0.039228  0.297415  8369
# 3     8909     2.115114e+12  0.743560  0.217500  0.038940  0.295380  8369
# 4     7653     3.643635e+11  0.775447  0.195013  0.029540  0.254094  5069
#
#      Pr20  total_peptides  total_protein_groups  total_precursors  \
# ...

# %%
df['method'].unique()
# Out:
# array(['SAX'], dtype=object)

# %%
methods = df['instrument'].unique()

# %%
methods
# Out:
# array(['SAX'], dtype=object)

# %%
fin = []
for el in methods:
    tmp_df = df[df['instrument'] == el]
    fin.append(np.log2(tmp_df['total_intensity']).tolist())

# %%
color_palette_red = ['#FBA08D', '#FA7A61', '#db4c2e']
fig = go.Figure()
for i, el in enumerate(fin):
    fig.add_trace(go.Box(y = el, boxpoints='all', pointpos=0, marker_color = color_palette_red[i], marker=dict(size=12, line = dict(width = 0.5))))
fig.update_layout(width = 600, height = 600, template = 'none', showlegend = False)
fig.update_yaxes(range = [34.9,42.1])
fig.write_image(r'D:\Projects\SPEC\figs_raw\Suppl_Figure1k.pdf', width = 600, height = 600)

# %% [markdown]
# # Figure 1L

# %%
experiment_dict = [
    {'instrument': '200 ng', 'method' : 'Bulk InSol', 'file_tags': ['E127_C1', 'E127_C2', 'E127_C3', 'E127_C4'], 'path': r'Z:\Tim_SPEC\figure3\insol_vs_spec\mouse_liver_FFPE.parquet'},
    {'instrument': '200 ng', 'method' : 'Single shot InSol', 'file_tags': ['E127_B1','E127_B2','E127_B3','E127_B4'], 'path': r'Z:\Tim_SPEC\figure3\insol_vs_spec\mouse_liver_FFPE.parquet'},
    {'instrument': '200 ng', 'method' : 'Single shot SPEC', 'file_tags': ['E127_A1', 'E127_A2', 'E127_A3', 'E127_A4'], 'path': r'Z:\Tim_SPEC\figure3\insol_vs_spec\mouse_liver_FFPE.parquet'},
]

# %%
from collections import defaultdict

# Group experiments by file
experiments_by_file = defaultdict(list)
for exp in experiment_dict:
    experiments_by_file[exp['path']].append(exp)

# Process
agg_stat_df = []
for path, experiments in experiments_by_file.items():
    df_full = cf.load_parquet_cached(path)
    df_full = df_full[df_full['PG.Q.Value'] < 0.01]
    
    for experiment in experiments:
        _df_agg = cf.process_experiment(
            df_full, 
            experiment, 
            protease='trypsin',
            max_missed_cleavages=2
        )
        agg_stat_df.append(_df_agg)

df = pd.concat(agg_stat_df, ignore_index=True)
# Out:
# d:\Projects\SPEC\scripts_for_figs\SPEC-figures\helper_functions.py:44: FutureWarning:
#
# DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#
# d:\Projects\SPEC\scripts_for_figs\SPEC-figures\helper_functions.py:44: FutureWarning:
#
# DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#
# d:\Projects\SPEC\scripts_for_figs\SPEC-figures\helper_functions.py:44: FutureWarning:
#
# ...

# %%
methods = df['method'].unique()

# %%
methods
# Out:
# array(['Bulk InSol', 'Single shot InSol', 'Single shot SPEC'],
#       dtype=object)

# %%
fin = []
for el in methods:
    tmp_df = df[df['method'] == el]
    fin.append(np.log2(tmp_df['total_intensity']).tolist())

# %%
fin
# Out:
# [[], [], []]

# %%
colors = ['#bd8078', '#623a73', '#ff0000']
fig = go.Figure()
for i, el in enumerate(fin):
    fig.add_trace(go.Box(y = el, boxpoints='all', pointpos=0, marker_color = colors[i], marker=dict(size=12, line = dict(width = 0.5))))
fig.update_layout(width = 600, height = 600, template = 'none', showlegend = False)
fig.update_yaxes(range = [32.9,41.1])
fig.write_image(r'D:\Projects\SPEC\figs_raw\Suppl_Figure1l.pdf', width = 600, height = 600)
